# %%
import intake
import xarray as xr
import zarr
import numpy as np

import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../src/')))
#sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../../weather_routing_old/src/')))

from weather_router import isochronal_weather_router, polar, point_validity, visualize
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='1f4dc091-8481-47e7-9a97-c89d16f78867'>
#   <div id="d5793fec-506b-4cfe-bce5-3756e3ff8633" data-root-id="1f4dc091-8481-47e7-9a97-c89d16f78867" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"a1204e6d-99a4-4006-802b-79bb5a40f07b":{"version":"3.8.1","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"e7337ccb-b874-4a73-85c5-5c4912df217e","attributes":{"notifications":{"type":"object","name":"Notifications","id":"67825369-740d-4a3b-a05f-6490ef388f42"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"1f4dc091-8481-47e7-9a97-c89d16f78867"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"8ae32931-7815-4d55-af68-842212f6b39b","attributes":{"plot_id":"1f4dc091-8481-47e7-9a97-c89d16f78867","comm_id":"9e861a50a361411783318241e2c7bc27","client_comm_id":"fc8a908e1d1640afade5908ece9729ff"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"a1204e6d-99a4-4006-802b-79bb5a40f07b","roots":{"1f4dc091-8481-47e7-9a97-c89d16f78867":"d5793fec-506b-4cfe-bce5-3756e3ff8633"},"root_ids":["1f4dc091-8481-47e7-9a97-c89d16f78867"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
#LA = (33.6, -124)
#Honolulu = (21.3, -157.8)

Cape = (-34, 18)
Rio = (-22.9, -43.2)

min_lat = min(Cape[0], Rio[0]) - 5  
max_lat = max(Cape[0], Rio[0]) + 5  

min_lon = min(Cape[1], Rio[1]) - 1  
max_lon = max(Cape[1], Rio[1]) + 1

# %%
if not os.path.exists('cache.zarr/'):
    print('Downloading data...')
    ds = xr.open_zarr(
        'gs://gcp-public-data-arco-era5/ar/full_37-1h-0p25deg-chunk-1.zarr-v3',
        chunks=None,
        storage_options=dict(token='anon'),
    )
    ds = ds.rename({'latitude':'lat', 'longitude':'lon'})
    ds = ds[['10m_u_component_of_wind', '10m_v_component_of_wind']]
    ds.coords['lon'] = ((ds.coords['lon'] + 180) % 360) - 180
    ds = ds.sortby(ds.lon)
    ds = ds.sel(lat=slice(max_lat, min_lat), lon=slice(min_lon, max_lon))
    ds = ds.sel(time = slice('2025-01-01T12:00:00', '2025-01-18T12:00:00'))
    ds = ds.load()
    u10 = ds['10m_u_component_of_wind']
    v10 = ds['10m_v_component_of_wind']
    tws = xr.ufuncs.hypot(v10, u10)
    tws = tws*1.94384 #convert m/s to knots
    twd = (180 + np.rad2deg(np.arctan2(u10, v10))) % 360
    ds = tws.to_dataset(name = 'tws')
    ds['twd'] = twd
    ds.to_zarr('cache.zarr')
else:
    ds = xr.open_zarr('cache.zarr')

# %%
def get_wind(t, lat, lon):
    tws_sel = ds.tws.sel(time = t, method = 'nearest')
    tws_sel = tws_sel.sel(lat = lat, lon = lon, method = 'nearest')
    twd_sel = ds.twd.sel(time = t, method = 'nearest')
    twd_sel = twd_sel.sel(lat = lat, lon = lon, method = 'nearest')
    return (np.float32(twd_sel.values), np.float32(tws_sel.values))

# %%
volvo70_polar = polar.Polar('../test/volvo70.pol')

ds_lsm = xr.open_dataset('../src/weather_router/data/GEBCO_2025_land_mask_big_chunk.zarr').rename({'lat':'latitude', 'lon':'longitude'})
ds_lsm = ds_lsm.sortby('latitude', ascending = False)
ds_lsm = ds_lsm.fillna(0)

weatherrouter = isochronal_weather_router.weather_router(volvo70_polar, 
                                                         get_wind, 
                                                         time_steps = ds.time.values,
                                                         step = 1,
                                                         start_point = Cape,
                                                         end_point = Rio,
                                                         point_validity_file = ds_lsm,
                                                         point_validity_extent = [min_lat, min_lon, max_lat, max_lon],
                                                         spread = 130,
                                                         wake_lim = 30,
                                                         rounding = 2,
                                                         n_points=30,
                                                         )

# %%
weatherrouter.route()
# Out:
# step 1 number of isochrone points 13 dist to finish 3240.9
# step 2 number of isochrone points 18 dist to finish 3228.8
# step 3 number of isochrone points 20 dist to finish 3216.2
# step 4 number of isochrone points 22 dist to finish 3203.6
# step 5 number of isochrone points 23 dist to finish 3188.2
# step 6 number of isochrone points 23 dist to finish 3173.0
# step 7 number of isochrone points 22 dist to finish 3156.5
# step 8 number of isochrone points 25 dist to finish 3139.3
# step 9 number of isochrone points 27 dist to finish 3123.2
# step 10 number of isochrone points 23 dist to finish 3107.3
# step 11 number of isochrone points 27 dist to finish 3091.5
# step 12 number of isochrone points 25 dist to finish 3073.5
# step 13 number of isochrone points 26 dist to finish 3052.8
# step 14 number of isochrone points 25 dist to finish 3031.8
# step 15 number of isochrone points 22 dist to finish 3013.7
# step 16 number of isochrone points 21 dist to finish 2997.2
# step 17 number of isochrone points 22 dist to finish 2982.8
# step 18 number of isochrone points 26 dist to finish 2966.3
# step 19 number of isochrone points 22 dist to finish 2951.5
# step 20 number of isochrone points 25 dist to finish 2937.7
# step 21 number of isochrone points 25 dist to finish 2925.3
# step 22 number of isochrone points 26 dist to finish 2914.2
# step 23 number of isochrone points 26 dist to finish 2904.5
# step 24 number of isochrone points 28 dist to finish 2896.8
# step 25 number of isochrone points 27 dist to finish 2887.3
# step 26 number of isochrone points 27 dist to finish 2878.9
# step 27 number of isochrone points 27 dist to finish 2870.5
# step 28 number of isochrone points 28 dist to finish 2861.0
# step 29 number of isochrone points 28 dist to finish 2850.0
# step 30 number of isochrone points 30 dist to finish 2838.8
# step 31 number of isochrone points 27 dist to finish 2827.5
# step 32 number of isochrone points 30 dist to finish 2816.2
# step 33 number of isochrone points 29 dist to finish 2806.4
# step 34 number of isochrone points 29 dist to finish 2796.6
# step 35 number of isochrone points 30 dist to finish 2788.2
# step 36 number of isochrone points 27 dist to finish 2781.1
# step 37 number of isochrone points 26 dist to finish 2774.1
# step 38 number of isochrone points 28 dist to finish 2770.3
# step 39 number of isochrone points 29 dist to finish 2766.7
# step 40 number of isochrone points 26 dist to finish 2764.6
# step 41 number of isochrone points 26 dist to finish 2763.5
# step 42 number of isochrone points 29 dist to finish 2762.2
# step 43 number of isochrone points 26 dist to finish 2756.3
# step 44 number of isochrone points 29 dist to finish 2749.2
# step 45 number of isochrone points 27 dist to finish 2739.6
# step 46 number of isochrone points 25 dist to finish 2728.9
# step 47 number of isochrone points 24 dist to finish 2716.2
# step 48 number of isochrone points 24 dist to finish 2702.7
# step 49 number of isochrone points 24 dist to finish 2690.2
# step 50 number of isochrone points 28 dist to finish 2679.5
# step 51 number of isochrone points 24 dist to finish 2667.6
# step 52 number of isochrone points 25 dist to finish 2655.9
# step 53 number of isochrone points 30 dist to finish 2643.8
# step 54 number of isochrone points 22 dist to finish 2632.3
# step 55 number of isochrone points 23 dist to finish 2620.8
# step 56 number of isochrone points 27 dist to finish 2608.4
# step 57 number of isochrone points 29 dist to finish 2595.3
# step 58 number of isochrone points 24 dist to finish 2585.3
# step 59 number of isochrone points 23 dist to finish 2577.0
# step 60 number of isochrone points 19 dist to finish 2559.7
# step 61 number of isochrone points 23 dist to finish 2543.0
# step 62 number of isochrone points 29 dist to finish 2526.7
# step 63 number of isochrone points 23 dist to finish 2510.4
# step 64 number of isochrone points 25 dist to finish 2494.2
# step 65 number of isochrone points 26 dist to finish 2478.8
# step 66 number of isochrone points 25 dist to finish 2463.5
# step 67 number of isochrone points 26 dist to finish 2448.1
# step 68 number of isochrone points 24 dist to finish 2432.8
# step 69 number of isochrone points 27 dist to finish 2417.0
# step 70 number of isochrone points 25 dist to finish 2401.2
# step 71 number of isochrone points 24 dist to finish 2385.2
# step 72 number of isochrone points 28 dist to finish 2370.6
# step 73 number of isochrone points 26 dist to finish 2355.6
# step 74 number of isochrone points 29 dist to finish 2340.6
# step 75 number of isochrone points 28 dist to finish 2325.6
# step 76 number of isochrone points 28 dist to finish 2309.5
# step 77 number of isochrone points 27 dist to finish 2293.1
# step 78 number of isochrone points 27 dist to finish 2276.1
# step 79 number of isochrone points 27 dist to finish 2259.2
# step 80 number of isochrone points 29 dist to finish 2240.8
# step 81 number of isochrone points 27 dist to finish 2222.1
# step 82 number of isochrone points 29 dist to finish 2203.1
# step 83 number of isochrone points 28 dist to finish 2185.3
# step 84 number of isochrone points 28 dist to finish 2167.6
# step 85 number of isochrone points 28 dist to finish 2149.6
# step 86 number of isochrone points 29 dist to finish 2131.4
# step 87 number of isochrone points 26 dist to finish 2115.0
# step 88 number of isochrone points 28 dist to finish 2098.7
# step 89 number of isochrone points 28 dist to finish 2082.3
# step 90 number of isochrone points 27 dist to finish 2066.0
# step 91 number of isochrone points 27 dist to finish 2048.1
# step 92 number of isochrone points 27 dist to finish 2030.2
# step 93 number of isochrone points 28 dist to finish 2012.4
# step 94 number of isochrone points 29 dist to finish 1994.9
# step 95 number of isochrone points 26 dist to finish 1979.4
# step 96 number of isochrone points 26 dist to finish 1964.2
# step 97 number of isochrone points 27 dist to finish 1950.2
# step 98 number of isochrone points 27 dist to finish 1936.6
# step 99 number of isochrone points 27 dist to finish 1924.4
# step 100 number of isochrone points 27 dist to finish 1913.8
# step 101 number of isochrone points 26 dist to finish 1903.9
# step 102 number of isochrone points 25 dist to finish 1896.5
# step 103 number of isochrone points 27 dist to finish 1888.8
# step 104 number of isochrone points 27 dist to finish 1882.5
# step 105 number of isochrone points 26 dist to finish 1875.2
# step 106 number of isochrone points 27 dist to finish 1867.8
# step 107 number of isochrone points 29 dist to finish 1861.2
# step 108 number of isochrone points 29 dist to finish 1856.5
# step 109 number of isochrone points 27 dist to finish 1852.9
# step 110 number of isochrone points 27 dist to finish 1848.9
# step 111 number of isochrone points 29 dist to finish 1845.6
# step 112 number of isochrone points 30 dist to finish 1841.2
# step 113 number of isochrone points 29 dist to finish 1832.4
# step 114 number of isochrone points 29 dist to finish 1822.9
# step 115 number of isochrone points 28 dist to finish 1811.8
# step 116 number of isochrone points 27 dist to finish 1800.5
# step 117 number of isochrone points 28 dist to finish 1790.6
# step 118 number of isochrone points 29 dist to finish 1782.2
# step 119 number of isochrone points 28 dist to finish 1773.7
# step 120 number of isochrone points 29 dist to finish 1761.0
# step 121 number of isochrone points 27 dist to finish 1748.6
# step 122 number of isochrone points 27 dist to finish 1736.8
# step 123 number of isochrone points 28 dist to finish 1725.1
# step 124 number of isochrone points 27 dist to finish 1713.7
# step 125 number of isochrone points 25 dist to finish 1703.3
# step 126 number of isochrone points 26 dist to finish 1691.9
# step 127 number of isochrone points 28 dist to finish 1680.8
# step 128 number of isochrone points 28 dist to finish 1668.6
# step 129 number of isochrone points 26 dist to finish 1656.3
# step 130 number of isochrone points 25 dist to finish 1644.0
# step 131 number of isochrone points 27 dist to finish 1632.9
# step 132 number of isochrone points 24 dist to finish 1622.6
# step 133 number of isochrone points 24 dist to finish 1611.0
# step 134 number of isochrone points 22 dist to finish 1599.5
# step 135 number of isochrone points 22 dist to finish 1587.0
# step 136 number of isochrone points 24 dist to finish 1574.4
# step 137 number of isochrone points 25 dist to finish 1561.6
# step 138 number of isochrone points 24 dist to finish 1547.7
# step 139 number of isochrone points 25 dist to finish 1532.9
# step 140 number of isochrone points 24 dist to finish 1518.2
# step 141 number of isochrone points 25 dist to finish 1503.5
# step 142 number of isochrone points 19 dist to finish 1488.8
# step 143 number of isochrone points 20 dist to finish 1474.4
# step 144 number of isochrone points 21 dist to finish 1460.1
# step 145 number of isochrone points 21 dist to finish 1447.0
# step 146 number of isochrone points 26 dist to finish 1434.1
# step 147 number of isochrone points 23 dist to finish 1421.5
# step 148 number of isochrone points 27 dist to finish 1409.9
# step 149 number of isochrone points 24 dist to finish 1399.1
# step 150 number of isochrone points 25 dist to finish 1386.4
# step 151 number of isochrone points 23 dist to finish 1375.2
# step 152 number of isochrone points 26 dist to finish 1363.9
# step 153 number of isochrone points 24 dist to finish 1352.6
# step 154 number of isochrone points 23 dist to finish 1342.3
# step 155 number of isochrone points 24 dist to finish 1330.5
# step 156 number of isochrone points 22 dist to finish 1320.1
# step 157 number of isochrone points 24 dist to finish 1308.1
# step 158 number of isochrone points 21 dist to finish 1296.8
# step 159 number of isochrone points 22 dist to finish 1284.7
# step 160 number of isochrone points 22 dist to finish 1275.3
# step 161 number of isochrone points 25 dist to finish 1265.6
# step 162 number of isochrone points 25 dist to finish 1263.6
# step 163 number of isochrone points 21 dist to finish 1256.6
# step 164 number of isochrone points 18 dist to finish 1249.3
# step 165 number of isochrone points 19 dist to finish 1241.9
# step 166 number of isochrone points 14 dist to finish 1233.8
# step 167 number of isochrone points 14 dist to finish 1229.5
# step 168 number of isochrone points 15 dist to finish 1224.4
# step 169 number of isochrone points 17 dist to finish 1217.9
# step 170 number of isochrone points 15 dist to finish 1210.5
# step 171 number of isochrone points 18 dist to finish 1202.5
# step 172 number of isochrone points 21 dist to finish 1195.5
# step 173 number of isochrone points 18 dist to finish 1190.1
# step 174 number of isochrone points 15 dist to finish 1183.2
# step 175 number of isochrone points 16 dist to finish 1181.7
# step 176 number of isochrone points 17 dist to finish 1178.9
# step 177 number of isochrone points 14 dist to finish 1175.4
# step 178 number of isochrone points 22 dist to finish 1169.0
# step 179 number of isochrone points 18 dist to finish 1161.9
# step 180 number of isochrone points 21 dist to finish 1154.1
# step 181 number of isochrone points 20 dist to finish 1145.5
# step 182 number of isochrone points 23 dist to finish 1138.4
# step 183 number of isochrone points 23 dist to finish 1132.1
# step 184 number of isochrone points 25 dist to finish 1126.4
# step 185 number of isochrone points 23 dist to finish 1121.7
# step 186 number of isochrone points 26 dist to finish 1113.8
# step 187 number of isochrone points 27 dist to finish 1104.7
# step 188 number of isochrone points 27 dist to finish 1096.8
# step 189 number of isochrone points 30 dist to finish 1092.6
# step 190 number of isochrone points 29 dist to finish 1090.8
# step 191 number of isochrone points 28 dist to finish 1089.9
# step 192 number of isochrone points 29 dist to finish 1087.0
# step 193 number of isochrone points 29 dist to finish 1085.1
# step 194 number of isochrone points 27 dist to finish 1082.0
# step 195 number of isochrone points 29 dist to finish 1079.8
# step 196 number of isochrone points 27 dist to finish 1075.3
# step 197 number of isochrone points 25 dist to finish 1071.9
# step 198 number of isochrone points 26 dist to finish 1067.6
# step 199 number of isochrone points 26 dist to finish 1066.4
# step 200 number of isochrone points 30 dist to finish 1065.5
# step 201 number of isochrone points 27 dist to finish 1060.2
# step 202 number of isochrone points 28 dist to finish 1054.9
# step 203 number of isochrone points 30 dist to finish 1050.7
# step 204 number of isochrone points 29 dist to finish 1046.1
# step 205 number of isochrone points 29 dist to finish 1037.6
# step 206 number of isochrone points 26 dist to finish 1029.7
# step 207 number of isochrone points 25 dist to finish 1026.0
# step 208 number of isochrone points 25 dist to finish 1020.6
# step 209 number of isochrone points 28 dist to finish 1014.7
# step 210 number of isochrone points 27 dist to finish 1007.1
# step 211 number of isochrone points 29 dist to finish 999.1
# step 212 number of isochrone points 29 dist to finish 988.3
# step 213 number of isochrone points 28 dist to finish 977.9
# step 214 number of isochrone points 28 dist to finish 966.4
# step 215 number of isochrone points 28 dist to finish 951.9
# step 216 number of isochrone points 27 dist to finish 939.0
# step 217 number of isochrone points 28 dist to finish 921.2
# step 218 number of isochrone points 27 dist to finish 905.7
# step 219 number of isochrone points 29 dist to finish 890.6
# step 220 number of isochrone points 28 dist to finish 875.7
# step 221 number of isochrone points 27 dist to finish 861.6
# step 222 number of isochrone points 27 dist to finish 856.5
# step 223 number of isochrone points 25 dist to finish 844.6
# step 224 number of isochrone points 24 dist to finish 833.6
# step 225 number of isochrone points 24 dist to finish 821.3
# step 226 number of isochrone points 25 dist to finish 804.9
# step 227 number of isochrone points 25 dist to finish 793.0
# step 228 number of isochrone points 21 dist to finish 782.6
# step 229 number of isochrone points 26 dist to finish 768.1
# step 230 number of isochrone points 25 dist to finish 749.3
# step 231 number of isochrone points 26 dist to finish 730.1
# step 232 number of isochrone points 24 dist to finish 709.6
# step 233 number of isochrone points 24 dist to finish 688.3
# step 234 number of isochrone points 23 dist to finish 666.0
# step 235 number of isochrone points 23 dist to finish 654.6
# step 236 number of isochrone points 24 dist to finish 646.7
# step 237 number of isochrone points 24 dist to finish 634.2
# step 238 number of isochrone points 25 dist to finish 620.5
# step 239 number of isochrone points 26 dist to finish 619.5
# step 240 number of isochrone points 25 dist to finish 606.6
# step 241 number of isochrone points 27 dist to finish 588.5
# step 242 number of isochrone points 28 dist to finish 567.4
# step 243 number of isochrone points 28 dist to finish 548.0
# step 244 number of isochrone points 28 dist to finish 531.7
# step 245 number of isochrone points 29 dist to finish 513.6
# step 246 number of isochrone points 27 dist to finish 501.6
# step 247 number of isochrone points 28 dist to finish 483.3
# step 248 number of isochrone points 29 dist to finish 468.8
# step 249 number of isochrone points 29 dist to finish 455.3
# step 250 number of isochrone points 30 dist to finish 441.3
# step 251 number of isochrone points 30 dist to finish 424.0
# step 252 number of isochrone points 30 dist to finish 410.4
# step 253 number of isochrone points 30 dist to finish 394.2
# step 254 number of isochrone points 30 dist to finish 387.5
# step 255 number of isochrone points 30 dist to finish 376.3
# step 256 number of isochrone points 29 dist to finish 368.0
# step 257 number of isochrone points 29 dist to finish 359.7
# step 258 number of isochrone points 30 dist to finish 350.8
# step 259 number of isochrone points 29 dist to finish 344.6
# step 260 number of isochrone points 28 dist to finish 335.6
# step 261 number of isochrone points 27 dist to finish 327.6
# step 262 number of isochrone points 23 dist to finish 334.9
# step 263 number of isochrone points 28 dist to finish 326.5
# step 264 number of isochrone points 27 dist to finish 317.9
# step 265 number of isochrone points 29 dist to finish 309.6
# step 266 number of isochrone points 29 dist to finish 300.9
# step 267 number of isochrone points 26 dist to finish 291.9
# step 268 number of isochrone points 26 dist to finish 282.8
# step 269 number of isochrone points 26 dist to finish 272.5
# step 270 number of isochrone points 24 dist to finish 264.4
# step 271 number of isochrone points 26 dist to finish 256.7
# step 272 number of isochrone points 24 dist to finish 249.3
# step 273 number of isochrone points 25 dist to finish 242.4
# step 274 number of isochrone points 25 dist to finish 233.0
# step 275 number of isochrone points 25 dist to finish 226.0
# step 276 number of isochrone points 26 dist to finish 218.9
# step 277 number of isochrone points 26 dist to finish 212.5
# step 278 number of isochrone points 26 dist to finish 204.3
# step 279 number of isochrone points 27 dist to finish 198.0
# step 280 number of isochrone points 28 dist to finish 198.0
# step 281 number of isochrone points 27 dist to finish 199.9
# step 282 number of isochrone points 27 dist to finish 196.7
# step 283 number of isochrone points 27 dist to finish 190.4
# step 284 number of isochrone points 26 dist to finish 182.4
# step 285 number of isochrone points 26 dist to finish 175.2
# step 286 number of isochrone points 25 dist to finish 169.9
# step 287 number of isochrone points 25 dist to finish 163.1
# step 288 number of isochrone points 24 dist to finish 157.9
# step 289 number of isochrone points 26 dist to finish 151.7
# step 290 number of isochrone points 26 dist to finish 144.7
# step 291 number of isochrone points 26 dist to finish 136.7
# step 292 number of isochrone points 27 dist to finish 129.8
# step 293 number of isochrone points 27 dist to finish 124.2
# step 294 number of isochrone points 26 dist to finish 118.5
# step 295 number of isochrone points 30 dist to finish 110.7
# step 296 number of isochrone points 30 dist to finish 100.9
# step 297 number of isochrone points 28 dist to finish 92.6
# step 298 number of isochrone points 27 dist to finish 85.8
# step 299 number of isochrone points 28 dist to finish 80.8
# step 300 number of isochrone points 26 dist to finish 75.4
# step 301 number of isochrone points 27 dist to finish 70.9
# step 302 number of isochrone points 30 dist to finish 68.7
# step 303 number of isochrone points 30 dist to finish 67.2
# step 304 number of isochrone points 27 dist to finish 64.3
# step 305 number of isochrone points 29 dist to finish 58.8
# step 306 number of isochrone points 28 dist to finish 52.1
# step 307 number of isochrone points 28 dist to finish 47.9
# step 308 number of isochrone points 29 dist to finish 43.2
# step 309 number of isochrone points 27 dist to finish 39.1
# step 310 number of isochrone points 29 dist to finish 35.4
# step 311 number of isochrone points 28 dist to finish 34.6
# step 312 number of isochrone points 29 dist to finish 34.6
# step 313 number of isochrone points 27 dist to finish 33.8
# step 314 number of isochrone points 28 dist to finish 31.9
# step 315 number of isochrone points 26 dist to finish 29.6
# step 316 number of isochrone points 26 dist to finish 25.6
# step 317 number of isochrone points 22 dist to finish 20.8
# step 318 number of isochrone points 21 dist to finish 17.3
# reached dest

# %%
route_df = weatherrouter.get_fastest_route()
route_df
# Out:
#            lat        lon                time         twd        tws  \
# 0   -34.000000  18.000000 2025-01-01 12:00:00  232.094025  10.638941
# 1   -33.914427  17.768982 2025-01-01 13:00:00  235.547287  12.729176
# 2   -33.772229  17.515831 2025-01-01 14:00:00  229.544617  13.184561
# 3   -33.537334  17.311232 2025-01-01 15:00:00  221.543182  13.329449
# 4   -33.385604  17.042345 2025-01-01 16:00:00  219.955811  14.590051
# ..         ...        ...                 ...         ...        ...
# 314 -22.929808 -42.500087 2025-01-14 14:00:00  117.589088   4.348788
# 315 -22.925928 -42.519899 2025-01-14 15:00:00  127.943924   5.807455
# 316 -22.990929 -42.652809 2025-01-14 16:00:00  125.464264   6.686768
# 317 -23.013485 -42.792167 2025-01-14 17:00:00  120.179321   6.698034
# 318 -23.021453 -42.916730 2025-01-14 18:00:00  117.018646   6.937072
#
#                                            pos  \
# 0                                (-34.0, 18.0)
# 1     (-33.91442701217998, 17.768982280463707)
# 2     (-33.772228858767036, 17.51583059842409)
# 3     (-33.53733394471476, 17.311232239298327)
# 4      (-33.38560432044475, 17.04234458774852)
# ..                                         ...
# 314   (-22.92980803832688, -42.50008748434434)
# 315  (-22.925928411767877, -42.51989882367333)
# 316  (-22.990929180108857, -42.65280903671808)
# 317  (-23.013485098112604, -42.79216674046083)
# 318   (-23.02145295131117, -42.91672952410143)
#
#                                       next_pos     heading         twa  \
# 0     (-33.91442701217998, 17.768982280463707)  294.000000   61.905975
# 1     (-33.772228858767036, 17.51583059842409)  304.000000   68.452713
# 2     (-33.53733394471476, 17.311232239298327)  324.000000   94.455383
# 3      (-33.38560432044475, 17.04234458774852)  304.000000   82.456818
# 4    (-33.320751374990536, 16.732904045323465)  284.000000   64.044189
# ..                                         ...         ...         ...
# 314  (-22.925928411767877, -42.51989882367333)  282.000000  164.410912
# 315  (-22.990929180108857, -42.65280903671808)  242.000000  114.056076
# 316  (-23.013485098112604, -42.79216674046083)  260.000000  134.535736
# 317   (-23.02145295131117, -42.91672952410143)  266.000000  145.820679
# 318                             (-22.9, -43.2)  294.913479  177.894833
#
#      base_boat_speed  is_tacking  boat_speed  hours_elapsed  days_elapsed
# 0              12.60       False       12.60              0      0.000000
# 1              15.24       False       15.24              1      0.041667
# 2              17.42       False       17.42              2      0.083333
# 3              16.26       False       16.26              3      0.125000
# 4              16.00       False       16.00              4      0.166667
# ..               ...         ...         ...            ...           ...
# 314             2.24        True        1.12            314     13.083333
# 315             8.32       False        8.32            315     13.125000
# 316             7.82       False        7.82            316     13.166667
# 317             6.90       False        6.90            317     13.208333
# 318             3.60       False        3.60            318     13.250000
#
# [319 rows x 14 columns]

# %%
isochrones = weatherrouter.get_isochrones_latlon()

# %%
viz = visualize.visualize(ds.sel(time = slice(route_df.time.values[0], route_df.time.values[-1])), Cape, Rio, route_df, isochrone=isochrones, filename='route1')
viz.return_plot()
# Out:
# WARNING:param.main: axiswise option not found for image plot with bokeh; similar options include: ['yaxis', 'xaxis']
# WARNING:param.main: axiswise option not found for vectorfield plot with bokeh; similar options include: ['yaxis', 'xaxis']
# :DynamicMap   [time]
#    :Overlay
#       .WMTS.I        :WMTS   [Longitude,Latitude]
#       .Image.I       :Image   [lon,lat]   (tws)
#       .VectorField.I :VectorField   [lon,lat]   (twd_rad,tws)
#       .Points.I      :Points   [lon,lat]
#       .Points.II     :Points   [lon,lat]
#       .Path.I        :Path   [Longitude,Latitude]
#       .Points.III    :Points   [lon,lat]   (TWS,TWD,TWA,Boat Speed)
#       .Points.IV     :Points   [Longitude,Latitude]

# %%
initial_route = weatherrouter.get_fastest_route(stats=False)
initial_isochrones = weatherrouter.get_isochrones()

optimized_route = weatherrouter.optimize(initial_route, initial_isochrones)

# %%
route_df = weatherrouter.get_fastest_route(use_optimized = True)
route_df
# Out:
#            lat        lon                time         twd        tws  \
# 0   -34.000000  18.000000 2025-01-01 12:00:00  232.094025  10.638941
# 1   -33.914427  17.768982 2025-01-01 13:00:00  235.547287  12.729176
# 2   -33.772229  17.515831 2025-01-01 14:00:00  229.544617  13.184561
# 3   -33.537334  17.311232 2025-01-01 15:00:00  221.543182  13.329449
# 4   -33.385604  17.042345 2025-01-01 16:00:00  219.955811  14.590051
# ..         ...        ...                 ...         ...        ...
# 314 -22.929808 -42.500087 2025-01-14 14:00:00  117.589088   4.348788
# 315 -22.925928 -42.519899 2025-01-14 15:00:00  127.943924   5.807455
# 316 -22.990929 -42.652809 2025-01-14 16:00:00  125.464264   6.686768
# 317 -23.013485 -42.792167 2025-01-14 17:00:00  120.179321   6.698034
# 318 -23.021453 -42.916730 2025-01-14 18:00:00  117.018646   6.937072
#
#                                            pos  \
# 0                                (-34.0, 18.0)
# 1     (-33.91442701217998, 17.768982280463707)
# 2     (-33.772228858767036, 17.51583059842409)
# 3     (-33.53733394471476, 17.311232239298327)
# 4      (-33.38560432044475, 17.04234458774852)
# ..                                         ...
# 314   (-22.92980803832688, -42.50008748434434)
# 315  (-22.925928411767877, -42.51989882367333)
# 316  (-22.990929180108857, -42.65280903671808)
# 317  (-23.013485098112604, -42.79216674046083)
# 318   (-23.02145295131117, -42.91672952410143)
#
#                                       next_pos     heading         twa  \
# 0     (-33.91442701217998, 17.768982280463707)  294.000000   61.905975
# 1     (-33.772228858767036, 17.51583059842409)  304.000000   68.452713
# 2     (-33.53733394471476, 17.311232239298327)  324.000000   94.455383
# 3      (-33.38560432044475, 17.04234458774852)  304.000000   82.456818
# 4    (-33.320751374990536, 16.732904045323465)  284.000000   64.044189
# ..                                         ...         ...         ...
# 314  (-22.925928411767877, -42.51989882367333)  282.000000  164.410912
# 315  (-22.990929180108857, -42.65280903671808)  242.000000  114.056076
# 316  (-23.013485098112604, -42.79216674046083)  260.000000  134.535736
# 317   (-23.02145295131117, -42.91672952410143)  266.000000  145.820679
# 318                             (-22.9, -43.2)  294.913479  177.894833
#
#      base_boat_speed  is_tacking  boat_speed  hours_elapsed  days_elapsed
# 0              12.60       False       12.60              0      0.000000
# 1              15.24       False       15.24              1      0.041667
# 2              17.42       False       17.42              2      0.083333
# 3              16.26       False       16.26              3      0.125000
# 4              16.00       False       16.00              4      0.166667
# ..               ...         ...         ...            ...           ...
# 314             2.24        True        1.12            314     13.083333
# 315             8.32       False        8.32            315     13.125000
# 316             7.82       False        7.82            316     13.166667
# 317             6.90       False        6.90            317     13.208333
# 318             3.60       False        3.60            318     13.250000
#
# [319 rows x 14 columns]

# %%
restricted_isochrones = weatherrouter.get_optimized_isochrones_latlon()

# %%
viz = visualize.visualize(ds.sel(time = slice(route_df.time.values[0], route_df.time.values[-1])), Cape, Rio, route_df, isochrone=restricted_isochrones, filename='route1')
viz.return_plot()
# Out:
# WARNING:param.main: axiswise option not found for image plot with bokeh; similar options include: ['yaxis', 'xaxis']
# WARNING:param.main: axiswise option not found for vectorfield plot with bokeh; similar options include: ['yaxis', 'xaxis']
# :DynamicMap   [time]
#    :Overlay
#       .WMTS.I        :WMTS   [Longitude,Latitude]
#       .Image.I       :Image   [lon,lat]   (tws)
#       .VectorField.I :VectorField   [lon,lat]   (twd_rad,tws)
#       .Points.I      :Points   [lon,lat]
#       .Points.II     :Points   [lon,lat]
#       .Path.I        :Path   [Longitude,Latitude]
#       .Points.III    :Points   [lon,lat]   (TWS,TWD,TWA,Boat Speed)

# %%
ds_lsm = xr.open_dataset('s3://peterm790/GEBCO_2025_land_mask_big_chunk.zarr/',
                            engine = 'zarr',
                            storage_options={"anon": True})
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.local/share/mamba/envs/routing/lib/python3.10/site-packages/fsspec/registry.py:261, in get_filesystem_class(protocol)
#     260 try:
# --> 261     register_implementation(protocol, _import_class(bit["class"]))
#     262 except ImportError as e:
#
# File ~/.local/share/mamba/envs/routing/lib/python3.10/site-packages/fsspec/registry.py:296, in _import_class(fqp)
#     295 is_s3 = mod == "s3fs"
# --> 296 mod = importlib.import_module(mod)
#     297 if is_s3 and mod.__version__.split(".") < ["0", "5"]:
#
# File ~/.local/share/mamba/envs/routing/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1004, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 's3fs'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 ds_lsm = xr.open_dataset('s3://peterm790/GEBCO_2025_land_mask_big_chunk.zarr/',
#       2                             engine = 'zarr',
#       3                             storage_options={"anon": True})
#
# File ~/.local/share/mamba/envs/routing/lib/python3.10/site-packages/xarray/backends/api.py:687, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     675 decoders = _resolve_decoders_kwargs(
#     676     decode_cf,
#     677     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     683     decode_coords=decode_coords,
#     684 )
#     686 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 687 backend_ds = backend.open_dataset(
#     688     filename_or_obj,
#     689     drop_variables=drop_variables,
#     690     **decoders,
#     691     **kwargs,
#     692 )
#     693 ds = _dataset_from_backend_dataset(
#     694     backend_ds,
#     695     filename_or_obj,
#    (...)
#     705     **kwargs,
#     706 )
#     707 return ds
#
# File ~/.local/share/mamba/envs/routing/lib/python3.10/site-packages/xarray/backends/zarr.py:1578, in ZarrBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, synchronizer, consolidated, chunk_store, storage_options, zarr_version, zarr_format, store, engine, use_zarr_fill_value_as_mask, cache_members)
#    1576 filename_or_obj = _normalize_path(filename_or_obj)
#    1577 if not store:
# -> 1578     store = ZarrStore.open_group(
#    1579         filename_or_obj,
#    1580         group=group,
#    1581         mode=mode,
#    1582         synchronizer=synchronizer,
#    1583         consolidated=consolidated,
#    1584         consolidate_on_close=False,
#    1585         chunk_store=chunk_store,
#    1586         storage_options=storage_options,
#    1587         zarr_version=zarr_version,
#    1588         use_zarr_fill_value_as_mask=None,
#    1589         zarr_format=zarr_format,
#    1590         cache_members=cache_members,
#    1591     )
#    1593 store_entrypoint = StoreBackendEntrypoint()
#    1594 with close_on_error(store):
#
# File ~/.local/share/mamba/envs/routing/lib/python3.10/site-packages/xarray/backends/zarr.py:664, in ZarrStore.open_group(cls, store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, append_dim, write_region, safe_chunks, align_chunks, zarr_version, zarr_format, use_zarr_fill_value_as_mask, write_empty, cache_members)
#     638 @classmethod
#     639 def open_group(
#     640     cls,
#    (...)
#     657     cache_members: bool = True,
#     658 ):
#     659     (
#     660         zarr_group,
#     661         consolidate_on_close,
#     662         close_store_on_close,
#     663         use_zarr_fill_value_as_mask,
# --> 664     ) = _get_open_params(
#     665         store=store,
#     666         mode=mode,
#     667         synchronizer=synchronizer,
#     668         group=group,
#     669         consolidated=consolidated,
#     670         consolidate_on_close=consolidate_on_close,
#     671         chunk_store=chunk_store,
#     672         storage_options=storage_options,
#     673         zarr_version=zarr_version,
#     674         use_zarr_fill_value_as_mask=use_zarr_fill_value_as_mask,
#     675         zarr_format=zarr_format,
#     676     )
#     678     return cls(
#     679         zarr_group,
#     680         mode,
#    (...)
#     689         cache_members=cache_members,
#     690     )
#
# File ~/.local/share/mamba/envs/routing/lib/python3.10/site-packages/xarray/backends/zarr.py:1781, in _get_open_params(store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, zarr_version, use_zarr_fill_value_as_mask, zarr_format)
#    1778 elif consolidated is None:
#    1779     # same but with more error handling in case no consolidated metadata found
#    1780     try:
# -> 1781         zarr_root_group = zarr.open_consolidated(store, **open_kwargs)
#    1782     except (ValueError, KeyError):
#    1783         # ValueError in zarr-python 3.x, KeyError in 2.x.
#    1784         try:
#
# File ~/.local/share/mamba/envs/routing/lib/python3.10/site-packages/zarr/convenience.py:1343, in open_consolidated(store, metadata_key, mode, **kwargs)
#    1341 # normalize parameters
#    1342 zarr_version = kwargs.get("zarr_version")
# -> 1343 store = normalize_store_arg(
#    1344     store, storage_options=kwargs.get("storage_options"), mode=mode, zarr_version=zarr_version
#    1345 )
#    1346 if mode not in {"r", "r+"}:
#    1347     raise ValueError(f"invalid mode, expected either 'r' or 'r+'; found {mode!r}")
#
# File ~/.local/share/mamba/envs/routing/lib/python3.10/site-packages/zarr/storage.py:201, in normalize_store_arg(store, storage_options, mode, zarr_version)
#     199 else:
#     200     raise ValueError("zarr_version must be either 2 or 3")
# --> 201 return normalize_store(store, storage_options, mode)
#
# File ~/.local/share/mamba/envs/routing/lib/python3.10/site-packages/zarr/storage.py:171, in _normalize_store_arg_v2(store, storage_options, mode)
#     169 if isinstance(store, str):
#     170     if "://" in store or "::" in store:
# --> 171         return FSStore(store, mode=mode, **(storage_options or {}))
#     172     elif storage_options:
#     173         raise ValueError("storage_options passed with non-fsspec path")
#
# File ~/.local/share/mamba/envs/routing/lib/python3.10/site-packages/zarr/storage.py:1384, in FSStore.__init__(self, url, normalize_keys, key_separator, mode, exceptions, dimension_separator, fs, check, create, missing_exceptions, **storage_options)
#    1382 if protocol in (None, "file") and not storage_options.get("auto_mkdir"):
#    1383     storage_options["auto_mkdir"] = True
# -> 1384 self.map = fsspec.get_mapper(url, **{**mapper_options, **storage_options})
#    1385 self.fs = self.map.fs  # for direct operations
#    1386 self.path = self.fs._strip_protocol(url)
#
# File ~/.local/share/mamba/envs/routing/lib/python3.10/site-packages/fsspec/mapping.py:249, in get_mapper(url, check, create, missing_exceptions, alternate_root, **kwargs)
#     218 """Create key-value interface for given URL and options
#     219
#     220 The URL will be of the form "protocol://location" and point to the root
#    (...)
#     246 ``FSMap`` instance, the dict-like key-value store.
#     247 """
#     248 # Removing protocol here - could defer to each open() on the backend
# --> 249 fs, urlpath = url_to_fs(url, **kwargs)
#     250 root = alternate_root if alternate_root is not None else urlpath
#     251 return FSMap(root, fs, check, create, missing_exceptions=missing_exceptions)
#
# File ~/.local/share/mamba/envs/routing/lib/python3.10/site-packages/fsspec/core.py:403, in url_to_fs(url, **kwargs)
#     392 known_kwargs = {
#     393     "compression",
#     394     "encoding",
#    (...)
#     400     "num",
#     401 }
#     402 kwargs = {k: v for k, v in kwargs.items() if k not in known_kwargs}
# --> 403 chain = _un_chain(url, kwargs)
#     404 inkwargs = {}
#     405 # Reverse iterate the chain, creating a nested target_* structure
#
# File ~/.local/share/mamba/envs/routing/lib/python3.10/site-packages/fsspec/core.py:351, in _un_chain(path, kwargs)
#     349 for bit in reversed(bits):
#     350     protocol = kwargs.pop("protocol", None) or split_protocol(bit)[0] or "file"
# --> 351     cls = get_filesystem_class(protocol)
#     352     extra_kwargs = cls._get_kwargs_from_urls(bit)
#     353     kws = kwargs.pop(protocol, {})
#
# File ~/.local/share/mamba/envs/routing/lib/python3.10/site-packages/fsspec/registry.py:263, in get_filesystem_class(protocol)
#     261         register_implementation(protocol, _import_class(bit["class"]))
#     262     except ImportError as e:
# --> 263         raise ImportError(bit.get("err")) from e
#     264 cls = registry[protocol]
#     265 if getattr(cls, "protocol", None) in ("abstract", None):
#
# ImportError: Install s3fs to access S3

# %%
import s3fs

fs = s3fs.S3FileSystem(anon=True)
fs.ls("peterm790/GEBCO_2025_land_mask_big_chunk.zarr")
# Out:
# ['peterm790/GEBCO_2025_land_mask_big_chunk.zarr/lat',
#  'peterm790/GEBCO_2025_land_mask_big_chunk.zarr/lon',
#  'peterm790/GEBCO_2025_land_mask_big_chunk.zarr/lsm']
