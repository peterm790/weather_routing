# %%
import intake
import xarray as xr
import zarr
import numpy as np

import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../src/')))
#sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../../weather_routing_old/src/')))

from weather_router import isochronal_weather_router, polar, point_validity, visualize
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='28cf077c-1f0c-4ffd-9b64-341602fc07a5'>
#   <div id="b75b755d-6975-4468-a66d-fa51d6292a22" data-root-id="28cf077c-1f0c-4ffd-9b64-341602fc07a5" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"392702b2-e6ce-43fc-b77b-c3039c21c62c":{"version":"3.8.1","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"39c90e70-4ad6-4373-9955-ec073bb4da0c","attributes":{"notifications":{"type":"object","name":"Notifications","id":"1977697a-be0d-4c22-99bc-ffaa8c320422"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"28cf077c-1f0c-4ffd-9b64-341602fc07a5"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"768a160f-de90-438e-95ac-8e18fca6f195","attributes":{"plot_id":"28cf077c-1f0c-4ffd-9b64-341602fc07a5","comm_id":"99dc4b3215ae476e96bfecfd48c2b3ab","client_comm_id":"75638b2ec6614094a7c25b251065b9a1"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"392702b2-e6ce-43fc-b77b-c3039c21c62c","roots":{"28cf077c-1f0c-4ffd-9b64-341602fc07a5":"b75b755d-6975-4468-a66d-fa51d6292a22"},"root_ids":["28cf077c-1f0c-4ffd-9b64-341602fc07a5"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
#LA = (33.6, -124)
#Honolulu = (21.3, -157.8)

Cape = (-34, 18)
Rio = (-22.9, -43.2)

min_lat = min(Cape[0], Rio[0]) - 5  
max_lat = max(Cape[0], Rio[0]) + 5  

min_lon = min(Cape[1], Rio[1]) - 1  
max_lon = max(Cape[1], Rio[1]) + 1

# %%
if not os.path.exists('cache.zarr/'):
    print('Downloading data...')
    ds = xr.open_zarr(
        'gs://gcp-public-data-arco-era5/ar/full_37-1h-0p25deg-chunk-1.zarr-v3',
        chunks=None,
        storage_options=dict(token='anon'),
    )
    ds = ds.rename({'latitude':'lat', 'longitude':'lon'})
    ds = ds[['10m_u_component_of_wind', '10m_v_component_of_wind']]
    ds.coords['lon'] = ((ds.coords['lon'] + 180) % 360) - 180
    ds = ds.sortby(ds.lon)
    ds = ds.sel(lat=slice(max_lat, min_lat), lon=slice(min_lon, max_lon))
    ds = ds.sel(time = slice('2025-01-01T12:00:00', '2025-01-18T12:00:00'))
    ds = ds.load()
    u10 = ds['10m_u_component_of_wind']
    v10 = ds['10m_v_component_of_wind']
    tws = xr.ufuncs.hypot(v10, u10)
    tws = tws*1.94384 #convert m/s to knots
    twd = (180 + np.rad2deg(np.arctan2(u10, v10))) % 360
    ds = tws.to_dataset(name = 'tws')
    ds['twd'] = twd
    ds.to_zarr('cache.zarr')
else:
    ds = xr.open_zarr('cache.zarr')
# Out:
# Downloading data...

# %%
#ds = ds.isel(time = slice(72,-1))

# %%
def get_wind(t, lat, lon):
    tws_sel = ds.tws.sel(time = t, method = 'nearest')
    tws_sel = tws_sel.sel(lat = lat, lon = lon, method = 'nearest')
    twd_sel = ds.twd.sel(time = t, method = 'nearest')
    twd_sel = twd_sel.sel(lat = lat, lon = lon, method = 'nearest')
    return (np.float32(twd_sel.values), np.float32(tws_sel.values))

# %%
volvo70_polar = polar.Polar('../test/volvo70.pol')

point_valid = point_validity.land_sea_mask().point_validity_arr

weatherrouter = isochronal_weather_router.weather_router(volvo70_polar, 
                                                         get_wind, 
                                                         time_steps = ds.time.values,
                                                         step = 1,
                                                         start_point = Cape,
                                                         end_point = Rio,
                                                         point_validity_extent = [min_lat, min_lon, max_lat, max_lon],
                                                         spread = 130,
                                                         wake_lim = 30,
                                                         rounding = 2,
                                                         n_points=30,
                                                         )

# %%
weatherrouter.route()
# Out:
# step 1 number of isochrone points 13 dist to finish 3240.9
# step 2 number of isochrone points 18 dist to finish 3228.8
# step 3 number of isochrone points 20 dist to finish 3216.2
# step 4 number of isochrone points 22 dist to finish 3203.6
# step 5 number of isochrone points 23 dist to finish 3188.2
# step 6 number of isochrone points 23 dist to finish 3173.0
# step 7 number of isochrone points 22 dist to finish 3156.5
# step 8 number of isochrone points 25 dist to finish 3139.3
# step 9 number of isochrone points 27 dist to finish 3123.2
# step 10 number of isochrone points 23 dist to finish 3107.3
# step 11 number of isochrone points 27 dist to finish 3091.5
# step 12 number of isochrone points 25 dist to finish 3073.5
# step 13 number of isochrone points 26 dist to finish 3052.8
# step 14 number of isochrone points 25 dist to finish 3031.8
# step 15 number of isochrone points 22 dist to finish 3013.7
# step 16 number of isochrone points 21 dist to finish 2997.2
# step 17 number of isochrone points 22 dist to finish 2982.8
# step 18 number of isochrone points 26 dist to finish 2966.3
# step 19 number of isochrone points 22 dist to finish 2951.5
# step 20 number of isochrone points 25 dist to finish 2937.7
# step 21 number of isochrone points 25 dist to finish 2925.3
# step 22 number of isochrone points 26 dist to finish 2914.2
# step 23 number of isochrone points 26 dist to finish 2904.5
# step 24 number of isochrone points 28 dist to finish 2896.8
# step 25 number of isochrone points 27 dist to finish 2887.3
# step 26 number of isochrone points 27 dist to finish 2878.9
# step 27 number of isochrone points 27 dist to finish 2870.5
# step 28 number of isochrone points 28 dist to finish 2861.0
# step 29 number of isochrone points 28 dist to finish 2850.0
# step 30 number of isochrone points 30 dist to finish 2838.8
# step 31 number of isochrone points 27 dist to finish 2827.5
# step 32 number of isochrone points 30 dist to finish 2816.2
# step 33 number of isochrone points 29 dist to finish 2806.4
# step 34 number of isochrone points 29 dist to finish 2796.6
# step 35 number of isochrone points 30 dist to finish 2788.2
# step 36 number of isochrone points 28 dist to finish 2781.1
# step 37 number of isochrone points 27 dist to finish 2774.1
# step 38 number of isochrone points 30 dist to finish 2770.3
# step 39 number of isochrone points 27 dist to finish 2766.7
# step 40 number of isochrone points 28 dist to finish 2764.6
# step 41 number of isochrone points 24 dist to finish 2763.5
# step 42 number of isochrone points 25 dist to finish 2762.2
# step 43 number of isochrone points 25 dist to finish 2756.3
# step 44 number of isochrone points 23 dist to finish 2749.2
# step 45 number of isochrone points 27 dist to finish 2739.6
# step 46 number of isochrone points 26 dist to finish 2728.9
# step 47 number of isochrone points 25 dist to finish 2716.2
# step 48 number of isochrone points 26 dist to finish 2702.7
# step 49 number of isochrone points 25 dist to finish 2690.2
# step 50 number of isochrone points 27 dist to finish 2679.5
# step 51 number of isochrone points 28 dist to finish 2667.6
# step 52 number of isochrone points 30 dist to finish 2655.9
# step 53 number of isochrone points 29 dist to finish 2643.8
# step 54 number of isochrone points 25 dist to finish 2632.3
# step 55 number of isochrone points 29 dist to finish 2620.8
# step 56 number of isochrone points 27 dist to finish 2608.4
# step 57 number of isochrone points 27 dist to finish 2595.3
# step 58 number of isochrone points 30 dist to finish 2585.3
# step 59 number of isochrone points 29 dist to finish 2577.0
# step 60 number of isochrone points 25 dist to finish 2559.7
# step 61 number of isochrone points 25 dist to finish 2543.0
# step 62 number of isochrone points 25 dist to finish 2526.7
# step 63 number of isochrone points 21 dist to finish 2510.4
# step 64 number of isochrone points 24 dist to finish 2494.2
# step 65 number of isochrone points 26 dist to finish 2478.8
# step 66 number of isochrone points 28 dist to finish 2463.5
# step 67 number of isochrone points 24 dist to finish 2448.1
# step 68 number of isochrone points 27 dist to finish 2432.8
# step 69 number of isochrone points 29 dist to finish 2417.0
# step 70 number of isochrone points 28 dist to finish 2401.2
# step 71 number of isochrone points 25 dist to finish 2385.2
# step 72 number of isochrone points 27 dist to finish 2369.7
# step 73 number of isochrone points 24 dist to finish 2354.7
# step 74 number of isochrone points 28 dist to finish 2339.7
# step 75 number of isochrone points 26 dist to finish 2324.6
# step 76 number of isochrone points 25 dist to finish 2308.2
# step 77 number of isochrone points 26 dist to finish 2291.7
# step 78 number of isochrone points 24 dist to finish 2274.8
# step 79 number of isochrone points 27 dist to finish 2257.9
# step 80 number of isochrone points 23 dist to finish 2239.5
# step 81 number of isochrone points 24 dist to finish 2220.7
# step 82 number of isochrone points 24 dist to finish 2201.7
# step 83 number of isochrone points 24 dist to finish 2183.7
# step 84 number of isochrone points 26 dist to finish 2165.8
# step 85 number of isochrone points 23 dist to finish 2147.8
# step 86 number of isochrone points 24 dist to finish 2129.6
# step 87 number of isochrone points 28 dist to finish 2111.6
# step 88 number of isochrone points 24 dist to finish 2095.2
# step 89 number of isochrone points 26 dist to finish 2078.8
# step 90 number of isochrone points 23 dist to finish 2062.5
# step 91 number of isochrone points 20 dist to finish 2044.6
# step 92 number of isochrone points 23 dist to finish 2026.7
# step 93 number of isochrone points 22 dist to finish 2009.0
# step 94 number of isochrone points 20 dist to finish 1991.5
# step 95 number of isochrone points 22 dist to finish 1975.9
# step 96 number of isochrone points 25 dist to finish 1961.2
# step 97 number of isochrone points 23 dist to finish 1947.2
# step 98 number of isochrone points 19 dist to finish 1933.6
# step 99 number of isochrone points 18 dist to finish 1921.3
# step 100 number of isochrone points 17 dist to finish 1909.5
# step 101 number of isochrone points 20 dist to finish 1899.6
# step 102 number of isochrone points 23 dist to finish 1892.2
# step 103 number of isochrone points 24 dist to finish 1884.9
# step 104 number of isochrone points 22 dist to finish 1878.6
# step 105 number of isochrone points 22 dist to finish 1871.2
# step 106 number of isochrone points 23 dist to finish 1864.2
# step 107 number of isochrone points 27 dist to finish 1857.5
# step 108 number of isochrone points 27 dist to finish 1852.9
# step 109 number of isochrone points 28 dist to finish 1847.6
# step 110 number of isochrone points 26 dist to finish 1840.8
# step 111 number of isochrone points 27 dist to finish 1831.9
# step 112 number of isochrone points 29 dist to finish 1822.9
# step 113 number of isochrone points 28 dist to finish 1815.5
# step 114 number of isochrone points 26 dist to finish 1806.9
# step 115 number of isochrone points 27 dist to finish 1796.2
# step 116 number of isochrone points 27 dist to finish 1784.6
# step 117 number of isochrone points 23 dist to finish 1774.9
# step 118 number of isochrone points 23 dist to finish 1765.1
# step 119 number of isochrone points 29 dist to finish 1755.5
# step 120 number of isochrone points 26 dist to finish 1742.8
# step 121 number of isochrone points 26 dist to finish 1730.4
# step 122 number of isochrone points 27 dist to finish 1717.9
# step 123 number of isochrone points 23 dist to finish 1705.5
# step 124 number of isochrone points 25 dist to finish 1695.1
# step 125 number of isochrone points 26 dist to finish 1684.8
# step 126 number of isochrone points 23 dist to finish 1673.4
# step 127 number of isochrone points 25 dist to finish 1663.5
# step 128 number of isochrone points 23 dist to finish 1652.3
# step 129 number of isochrone points 28 dist to finish 1641.1
# step 130 number of isochrone points 21 dist to finish 1629.9
# step 131 number of isochrone points 24 dist to finish 1621.7
# step 132 number of isochrone points 19 dist to finish 1612.4
# step 133 number of isochrone points 15 dist to finish 1603.1
# step 134 number of isochrone points 23 dist to finish 1593.7
# step 135 number of isochrone points 22 dist to finish 1583.1
# step 136 number of isochrone points 22 dist to finish 1572.5
# step 137 number of isochrone points 23 dist to finish 1562.1
# step 138 number of isochrone points 23 dist to finish 1550.5
# step 139 number of isochrone points 23 dist to finish 1538.8
# step 140 number of isochrone points 23 dist to finish 1525.0
# step 141 number of isochrone points 23 dist to finish 1510.9
# step 142 number of isochrone points 21 dist to finish 1496.7
# step 143 number of isochrone points 27 dist to finish 1482.6
# step 144 number of isochrone points 24 dist to finish 1467.6
# step 145 number of isochrone points 22 dist to finish 1453.0
# step 146 number of isochrone points 25 dist to finish 1438.0
# step 147 number of isochrone points 25 dist to finish 1424.1
# step 148 number of isochrone points 25 dist to finish 1410.2
# step 149 number of isochrone points 24 dist to finish 1396.3
# step 150 number of isochrone points 22 dist to finish 1382.9
# step 151 number of isochrone points 26 dist to finish 1370.5
# step 152 number of isochrone points 23 dist to finish 1358.0
# step 153 number of isochrone points 25 dist to finish 1346.5
# step 154 number of isochrone points 23 dist to finish 1333.7
# step 155 number of isochrone points 24 dist to finish 1323.1
# step 156 number of isochrone points 25 dist to finish 1311.2
# step 157 number of isochrone points 23 dist to finish 1298.4
# step 158 number of isochrone points 23 dist to finish 1285.6
# step 159 number of isochrone points 27 dist to finish 1273.9
# step 160 number of isochrone points 24 dist to finish 1262.2
# step 161 number of isochrone points 24 dist to finish 1251.6
# step 162 number of isochrone points 25 dist to finish 1241.1
# step 163 number of isochrone points 24 dist to finish 1230.4
# step 164 number of isochrone points 23 dist to finish 1221.0
# step 165 number of isochrone points 27 dist to finish 1211.5
# step 166 number of isochrone points 26 dist to finish 1203.9
# step 167 number of isochrone points 26 dist to finish 1196.5
# step 168 number of isochrone points 25 dist to finish 1189.0
# step 169 number of isochrone points 25 dist to finish 1181.4
# step 170 number of isochrone points 29 dist to finish 1171.7
# step 171 number of isochrone points 26 dist to finish 1163.4
# step 172 number of isochrone points 28 dist to finish 1155.9
# step 173 number of isochrone points 26 dist to finish 1148.5
# step 174 number of isochrone points 23 dist to finish 1141.2
# step 175 number of isochrone points 26 dist to finish 1134.5
# step 176 number of isochrone points 26 dist to finish 1129.3
# step 177 number of isochrone points 26 dist to finish 1125.3
# step 178 number of isochrone points 27 dist to finish 1118.1
# step 179 number of isochrone points 25 dist to finish 1112.3
# step 180 number of isochrone points 24 dist to finish 1104.6
# step 181 number of isochrone points 25 dist to finish 1097.9
# step 182 number of isochrone points 26 dist to finish 1088.0
# step 183 number of isochrone points 24 dist to finish 1077.4
# step 184 number of isochrone points 30 dist to finish 1062.4
# step 185 number of isochrone points 27 dist to finish 1046.0
# step 186 number of isochrone points 28 dist to finish 1031.6
# step 187 number of isochrone points 25 dist to finish 1018.5
# step 188 number of isochrone points 20 dist to finish 1005.4
# step 189 number of isochrone points 22 dist to finish 988.7
# step 190 number of isochrone points 16 dist to finish 972.0
# step 191 number of isochrone points 18 dist to finish 957.6
# step 192 number of isochrone points 18 dist to finish 940.3
# step 193 number of isochrone points 21 dist to finish 923.7
# step 194 number of isochrone points 24 dist to finish 906.7
# step 195 number of isochrone points 25 dist to finish 889.0
# step 196 number of isochrone points 23 dist to finish 878.2
# step 197 number of isochrone points 24 dist to finish 867.7
# step 198 number of isochrone points 26 dist to finish 856.8
# step 199 number of isochrone points 23 dist to finish 851.4
# step 200 number of isochrone points 25 dist to finish 843.6
# step 201 number of isochrone points 19 dist to finish 838.9
# step 202 number of isochrone points 17 dist to finish 840.3
# step 203 number of isochrone points 19 dist to finish 837.3
# step 204 number of isochrone points 16 dist to finish 846.9
# step 205 number of isochrone points 16 dist to finish 845.7
# step 206 number of isochrone points 14 dist to finish 836.0
# step 207 number of isochrone points 19 dist to finish 821.1
# step 208 number of isochrone points 17 dist to finish 805.4
# step 209 number of isochrone points 17 dist to finish 793.1
# step 210 number of isochrone points 19 dist to finish 775.0
# step 211 number of isochrone points 17 dist to finish 760.7
# step 212 number of isochrone points 15 dist to finish 743.1
# step 213 number of isochrone points 19 dist to finish 723.8
# step 214 number of isochrone points 19 dist to finish 703.2
# step 215 number of isochrone points 20 dist to finish 682.0
# step 216 number of isochrone points 19 dist to finish 661.3
# step 217 number of isochrone points 19 dist to finish 642.1
# step 218 number of isochrone points 24 dist to finish 622.0
# step 219 number of isochrone points 22 dist to finish 602.2
# step 220 number of isochrone points 21 dist to finish 581.6
# step 221 number of isochrone points 20 dist to finish 560.8
# step 222 number of isochrone points 19 dist to finish 539.4
# step 223 number of isochrone points 17 dist to finish 517.0
# step 224 number of isochrone points 20 dist to finish 495.6
# step 225 number of isochrone points 17 dist to finish 475.2
# step 226 number of isochrone points 21 dist to finish 463.1
# step 227 number of isochrone points 20 dist to finish 448.6
# step 228 number of isochrone points 22 dist to finish 432.4
# step 229 number of isochrone points 22 dist to finish 422.2
# step 230 number of isochrone points 21 dist to finish 416.1
# step 231 number of isochrone points 25 dist to finish 409.6
# step 232 number of isochrone points 27 dist to finish 394.8
# step 233 number of isochrone points 28 dist to finish 376.1
# step 234 number of isochrone points 28 dist to finish 358.5
# step 235 number of isochrone points 27 dist to finish 342.2
# step 236 number of isochrone points 28 dist to finish 327.7
# step 237 number of isochrone points 29 dist to finish 313.9
# step 238 number of isochrone points 29 dist to finish 302.2
# step 239 number of isochrone points 26 dist to finish 287.7
# step 240 number of isochrone points 30 dist to finish 273.7
# step 241 number of isochrone points 30 dist to finish 256.7
# step 242 number of isochrone points 29 dist to finish 240.6
# step 243 number of isochrone points 30 dist to finish 222.9
# step 244 number of isochrone points 27 dist to finish 206.7
# step 245 number of isochrone points 27 dist to finish 191.8
# step 246 number of isochrone points 27 dist to finish 178.2
# step 247 number of isochrone points 26 dist to finish 164.4
# step 248 number of isochrone points 23 dist to finish 153.0
# step 249 number of isochrone points 23 dist to finish 140.0
# step 250 number of isochrone points 21 dist to finish 128.2
# step 251 number of isochrone points 23 dist to finish 116.4
# step 252 number of isochrone points 25 dist to finish 106.7
# step 253 number of isochrone points 28 dist to finish 96.5
# step 254 number of isochrone points 27 dist to finish 88.3
# step 255 number of isochrone points 26 dist to finish 83.3
# step 256 number of isochrone points 27 dist to finish 80.0
# step 257 number of isochrone points 27 dist to finish 78.0
# step 258 number of isochrone points 25 dist to finish 75.8
# step 259 number of isochrone points 25 dist to finish 74.9
# step 260 number of isochrone points 24 dist to finish 73.5
# step 261 number of isochrone points 21 dist to finish 75.5
# step 262 number of isochrone points 27 dist to finish 74.1
# step 263 number of isochrone points 27 dist to finish 71.0
# step 264 number of isochrone points 27 dist to finish 66.9
# step 265 number of isochrone points 26 dist to finish 65.0
# step 266 number of isochrone points 28 dist to finish 64.1
# step 267 number of isochrone points 27 dist to finish 63.1
# step 268 number of isochrone points 29 dist to finish 62.3
# step 269 number of isochrone points 28 dist to finish 60.3
# step 270 number of isochrone points 27 dist to finish 56.2
# step 271 number of isochrone points 28 dist to finish 50.9
# step 272 number of isochrone points 26 dist to finish 44.1
# step 273 number of isochrone points 24 dist to finish 37.2
# step 274 number of isochrone points 23 dist to finish 33.1
# step 275 number of isochrone points 28 dist to finish 29.8
# step 276 number of isochrone points 26 dist to finish 26.2
# step 277 number of isochrone points 26 dist to finish 24.1
# step 278 number of isochrone points 23 dist to finish 21.7
# step 279 number of isochrone points 24 dist to finish 20.7
# step 280 number of isochrone points 22 dist to finish 19.2
# reached dest

# %%
route_df = weatherrouter.get_fastest_route()
route_df
# Out:
#            lat        lon                time         twd        tws  \
# 0   -34.000000  18.000000 2025-01-01 12:00:00  232.094025  10.638941
# 1   -33.914427  17.768982 2025-01-01 13:00:00  235.547287  12.729176
# 2   -33.772229  17.515831 2025-01-01 14:00:00  229.544617  13.184561
# 3   -33.537334  17.311232 2025-01-01 15:00:00  221.543182  13.329449
# 4   -33.385604  17.042345 2025-01-01 16:00:00  219.955811  14.590051
# ..         ...        ...                 ...         ...        ...
# 276 -23.325902 -43.093364 2025-01-13 00:00:00  141.784500   5.056849
# 277 -23.277346 -43.053536 2025-01-13 01:00:00  139.377045   4.103590
# 278 -23.201799 -42.984580 2025-01-13 02:00:00  139.020447   2.868200
# 279 -23.199133 -43.012153 2025-01-13 03:00:00  157.068924   2.066015
# 280 -23.192143 -43.060116 2025-01-13 04:00:00  185.851456   1.969275
#
#                                            pos  \
# 0                                (-34.0, 18.0)
# 1     (-33.91442701217998, 17.768982280463707)
# 2     (-33.772228858767036, 17.51583059842409)
# 3     (-33.53733394471476, 17.311232239298327)
# 4      (-33.38560432044475, 17.04234458774852)
# ..                                         ...
# 276  (-23.32590203422517, -43.093363636789505)
# 277  (-23.277346148175894, -43.05353609330827)
# 278  (-23.20179907715793, -42.984580282288704)
# 279  (-23.199132998842014, -43.01215295701329)
# 280  (-23.192143042544103, -43.06011582445876)
#
#                                       next_pos     heading         twa  \
# 0     (-33.91442701217998, 17.768982280463707)  294.000000   61.905975
# 1     (-33.772228858767036, 17.51583059842409)  304.000000   68.452713
# 2     (-33.53733394471476, 17.311232239298327)  324.000000   94.455383
# 3      (-33.38560432044475, 17.04234458774852)  304.000000   82.456818
# 4    (-33.320751374990536, 16.732904045323465)  284.000000   64.044189
# ..                                         ...         ...         ...
# 276  (-23.277346148175894, -43.05353609330827)   37.000000 -104.784500
# 277  (-23.20179907715793, -42.984580282288704)   40.000000  -99.377045
# 278  (-23.199132998842014, -43.01215295701329)  276.000000  136.979553
# 279  (-23.192143042544103, -43.06011582445876)  279.000000  121.931076
# 280                             (-22.9, -43.2)  336.193993  150.342538
#
#      base_boat_speed  is_tacking  boat_speed  hours_elapsed  days_elapsed
# 0              12.60       False       12.60              0      0.000000
# 1              15.24       False       15.24              1      0.041667
# 2              17.42       False       17.42              2      0.083333
# 3              16.26       False       16.26              3      0.125000
# 4              16.00       False       16.00              4      0.166667
# ..               ...         ...         ...            ...           ...
# 276             7.30        True        3.65            276     11.500000
# 277             5.92       False        5.92            277     11.541667
# 278             3.06        True        1.53            278     11.583333
# 279             2.68       False        2.68            279     11.625000
# 280             1.52       False        1.52            280     11.666667
#
# [281 rows x 14 columns]

# %%
isochrones = weatherrouter.get_isochrones_latlon()

# %%
viz = visualize.visualize(ds.sel(time = slice(route_df.time.values[0], route_df.time.values[-1])), Cape, Rio, route_df, isochrone=isochrones, filename='route1')
viz.return_plot()
# Out:
# WARNING:param.main: axiswise option not found for image plot with bokeh; similar options include: ['yaxis', 'xaxis']
# WARNING:param.main: axiswise option not found for vectorfield plot with bokeh; similar options include: ['yaxis', 'xaxis']
# BokehModel(combine_events=True, render_bundle={'docs_json': {'adbebb14-c7e4-4069-9e9d-bf0471b142c3': {'version…

# %%
initial_route = weatherrouter.get_fastest_route(stats=False)
initial_isochrones = weatherrouter.get_isochrones()

optimized_route = weatherrouter.optimize(initial_route, initial_isochrones)
# Out:
# step 1 number of isochrone points 13 dist to finish 3240.9
# step 2 number of isochrone points 40 dist to finish 3228.8
# step 3 number of isochrone points 57 dist to finish 3216.2
# step 4 number of isochrone points 26 dist to finish 3203.5
# step 5 number of isochrone points 59 dist to finish 3188.2
# step 6 number of isochrone points 31 dist to finish 3172.8
# step 7 number of isochrone points 32 dist to finish 3156.1
# step 8 number of isochrone points 50 dist to finish 3138.8
# step 9 number of isochrone points 49 dist to finish 3120.8
# step 10 number of isochrone points 59 dist to finish 3104.1
# step 11 number of isochrone points 34 dist to finish 3088.4
# step 12 number of isochrone points 54 dist to finish 3072.7
# step 13 number of isochrone points 29 dist to finish 3054.4
# step 14 number of isochrone points 44 dist to finish 3033.4
# step 15 number of isochrone points 41 dist to finish 3014.1
# step 16 number of isochrone points 47 dist to finish 2995.0
# step 17 number of isochrone points 52 dist to finish 2977.1
# step 18 number of isochrone points 55 dist to finish 2960.8
# step 19 number of isochrone points 55 dist to finish 2946.1
# step 20 number of isochrone points 48 dist to finish 2932.5
# step 21 number of isochrone points 45 dist to finish 2919.1
# step 22 number of isochrone points 48 dist to finish 2905.5
# step 23 number of isochrone points 57 dist to finish 2893.8
# step 24 number of isochrone points 33 dist to finish 2882.4
# step 25 number of isochrone points 57 dist to finish 2872.6
# step 26 number of isochrone points 31 dist to finish 2864.1
# step 27 number of isochrone points 55 dist to finish 2854.5
# step 28 number of isochrone points 59 dist to finish 2844.9
# step 29 number of isochrone points 35 dist to finish 2833.9
# step 30 number of isochrone points 60 dist to finish 2822.9
# step 31 number of isochrone points 35 dist to finish 2811.7
# step 32 number of isochrone points 52 dist to finish 2801.2
# step 33 number of isochrone points 40 dist to finish 2790.4
# step 34 number of isochrone points 40 dist to finish 2780.6
# step 35 number of isochrone points 58 dist to finish 2772.3
# step 36 number of isochrone points 44 dist to finish 2765.3
# step 37 number of isochrone points 45 dist to finish 2759.1
# step 38 number of isochrone points 39 dist to finish 2755.2
# step 39 number of isochrone points 38 dist to finish 2751.6
# step 40 number of isochrone points 41 dist to finish 2749.5
# step 41 number of isochrone points 37 dist to finish 2748.2
# step 42 number of isochrone points 41 dist to finish 2742.4
# step 43 number of isochrone points 55 dist to finish 2736.5
# step 44 number of isochrone points 34 dist to finish 2728.0
# step 45 number of isochrone points 55 dist to finish 2718.3
# step 46 number of isochrone points 35 dist to finish 2704.7
# step 47 number of isochrone points 36 dist to finish 2689.5
# step 48 number of isochrone points 39 dist to finish 2676.4
# step 49 number of isochrone points 39 dist to finish 2663.8
# step 50 number of isochrone points 42 dist to finish 2649.9
# step 51 number of isochrone points 35 dist to finish 2635.9
# step 52 number of isochrone points 36 dist to finish 2622.8
# step 53 number of isochrone points 38 dist to finish 2610.3
# step 54 number of isochrone points 36 dist to finish 2597.8
# step 55 number of isochrone points 37 dist to finish 2586.1
# step 56 number of isochrone points 54 dist to finish 2574.7
# step 57 number of isochrone points 48 dist to finish 2565.3
# step 58 number of isochrone points 32 dist to finish 2552.4
# step 59 number of isochrone points 23 dist to finish 2535.2
# step 60 number of isochrone points 24 dist to finish 2518.4
# step 61 number of isochrone points 29 dist to finish 2502.1
# step 62 number of isochrone points 30 dist to finish 2486.3
# step 63 number of isochrone points 33 dist to finish 2470.3
# step 64 number of isochrone points 34 dist to finish 2454.0
# step 65 number of isochrone points 31 dist to finish 2438.6
# step 66 number of isochrone points 28 dist to finish 2422.3
# step 67 number of isochrone points 37 dist to finish 2406.1
# step 68 number of isochrone points 46 dist to finish 2390.3
# step 69 number of isochrone points 51 dist to finish 2374.6
# step 70 number of isochrone points 52 dist to finish 2358.5
# step 71 number of isochrone points 48 dist to finish 2342.3
# step 72 number of isochrone points 58 dist to finish 2326.9
# step 73 number of isochrone points 36 dist to finish 2311.8
# step 74 number of isochrone points 57 dist to finish 2297.5
# step 75 number of isochrone points 37 dist to finish 2282.1
# step 76 number of isochrone points 55 dist to finish 2266.7
# step 77 number of isochrone points 35 dist to finish 2250.9
# step 78 number of isochrone points 55 dist to finish 2235.0
# step 79 number of isochrone points 28 dist to finish 2217.8
# step 80 number of isochrone points 48 dist to finish 2199.1
# step 81 number of isochrone points 55 dist to finish 2179.8
# step 82 number of isochrone points 31 dist to finish 2160.9
# step 83 number of isochrone points 47 dist to finish 2142.7
# step 84 number of isochrone points 51 dist to finish 2124.5
# step 85 number of isochrone points 51 dist to finish 2106.3
# step 86 number of isochrone points 56 dist to finish 2088.1
# step 87 number of isochrone points 55 dist to finish 2070.4
# step 88 number of isochrone points 38 dist to finish 2052.5
# step 89 number of isochrone points 57 dist to finish 2036.0
# step 90 number of isochrone points 53 dist to finish 2019.5
# step 91 number of isochrone points 53 dist to finish 2003.2
# step 92 number of isochrone points 50 dist to finish 1985.5
# step 93 number of isochrone points 54 dist to finish 1968.0
# step 94 number of isochrone points 31 dist to finish 1951.1
# step 95 number of isochrone points 53 dist to finish 1934.4
# step 96 number of isochrone points 32 dist to finish 1918.9
# step 97 number of isochrone points 50 dist to finish 1905.5
# step 98 number of isochrone points 52 dist to finish 1893.6
# step 99 number of isochrone points 23 dist to finish 1884.2
# step 100 number of isochrone points 53 dist to finish 1877.0
# step 101 number of isochrone points 34 dist to finish 1872.3
# step 102 number of isochrone points 31 dist to finish 1867.7
# step 103 number of isochrone points 59 dist to finish 1860.3
# step 104 number of isochrone points 32 dist to finish 1852.6
# step 105 number of isochrone points 38 dist to finish 1845.7
# step 106 number of isochrone points 33 dist to finish 1837.5
# step 107 number of isochrone points 35 dist to finish 1830.4
# step 108 number of isochrone points 43 dist to finish 1821.5
# step 109 number of isochrone points 47 dist to finish 1812.6
# step 110 number of isochrone points 41 dist to finish 1803.8
# step 111 number of isochrone points 39 dist to finish 1794.5
# step 112 number of isochrone points 35 dist to finish 1784.8
# step 113 number of isochrone points 28 dist to finish 1774.9
# step 114 number of isochrone points 33 dist to finish 1766.0
# step 115 number of isochrone points 52 dist to finish 1756.1
# step 116 number of isochrone points 28 dist to finish 1745.0
# step 117 number of isochrone points 58 dist to finish 1733.5
# step 118 number of isochrone points 29 dist to finish 1721.5
# step 119 number of isochrone points 33 dist to finish 1710.5
# step 120 number of isochrone points 27 dist to finish 1700.4
# step 121 number of isochrone points 27 dist to finish 1689.3
# step 122 number of isochrone points 28 dist to finish 1677.2
# step 123 number of isochrone points 29 dist to finish 1664.7
# step 124 number of isochrone points 57 dist to finish 1651.0
# step 125 number of isochrone points 27 dist to finish 1638.2
# step 126 number of isochrone points 53 dist to finish 1625.8
# step 127 number of isochrone points 30 dist to finish 1613.8
# step 128 number of isochrone points 60 dist to finish 1602.3
# step 129 number of isochrone points 33 dist to finish 1591.8
# step 130 number of isochrone points 60 dist to finish 1581.3
# step 131 number of isochrone points 40 dist to finish 1569.1
# step 132 number of isochrone points 37 dist to finish 1555.2
# step 133 number of isochrone points 60 dist to finish 1541.5
# step 134 number of isochrone points 40 dist to finish 1527.2
# step 135 number of isochrone points 56 dist to finish 1514.0
# step 136 number of isochrone points 35 dist to finish 1501.4
# step 137 number of isochrone points 60 dist to finish 1489.9
# step 138 number of isochrone points 56 dist to finish 1478.2
# step 139 number of isochrone points 57 dist to finish 1464.9
# step 140 number of isochrone points 40 dist to finish 1451.4
# step 141 number of isochrone points 58 dist to finish 1437.0
# step 142 number of isochrone points 60 dist to finish 1421.9
# step 143 number of isochrone points 34 dist to finish 1407.5
# step 144 number of isochrone points 55 dist to finish 1392.0
# step 145 number of isochrone points 42 dist to finish 1377.2
# step 146 number of isochrone points 55 dist to finish 1362.4
# step 147 number of isochrone points 58 dist to finish 1346.1
# step 148 number of isochrone points 60 dist to finish 1330.6
# step 149 number of isochrone points 43 dist to finish 1317.2
# step 150 number of isochrone points 58 dist to finish 1304.1
# step 151 number of isochrone points 46 dist to finish 1291.0
# step 152 number of isochrone points 51 dist to finish 1281.7
# step 153 number of isochrone points 60 dist to finish 1270.0
# step 154 number of isochrone points 48 dist to finish 1256.2
# step 155 number of isochrone points 58 dist to finish 1240.4
# step 156 number of isochrone points 60 dist to finish 1224.4
# step 157 number of isochrone points 41 dist to finish 1209.3
# step 158 number of isochrone points 40 dist to finish 1196.4
# step 159 number of isochrone points 50 dist to finish 1184.2
# step 160 number of isochrone points 33 dist to finish 1172.1
# step 161 number of isochrone points 44 dist to finish 1161.9
# step 162 number of isochrone points 47 dist to finish 1148.8
# step 163 number of isochrone points 59 dist to finish 1136.0
# step 164 number of isochrone points 33 dist to finish 1119.7
# step 165 number of isochrone points 47 dist to finish 1103.1
# step 166 number of isochrone points 60 dist to finish 1088.0
# step 167 number of isochrone points 32 dist to finish 1072.9
# step 168 number of isochrone points 49 dist to finish 1056.4
# step 169 number of isochrone points 28 dist to finish 1041.0
# step 170 number of isochrone points 51 dist to finish 1028.1
# step 171 number of isochrone points 32 dist to finish 1016.1
# step 172 number of isochrone points 43 dist to finish 1002.2
# step 173 number of isochrone points 45 dist to finish 987.0
# step 174 number of isochrone points 43 dist to finish 973.2
# step 175 number of isochrone points 47 dist to finish 960.4
# step 176 number of isochrone points 53 dist to finish 948.7
# step 177 number of isochrone points 54 dist to finish 934.8
# step 178 number of isochrone points 41 dist to finish 919.6
# step 179 number of isochrone points 59 dist to finish 905.7
# step 180 number of isochrone points 34 dist to finish 892.0
# step 181 number of isochrone points 59 dist to finish 877.1
# step 182 number of isochrone points 35 dist to finish 864.5
# step 183 number of isochrone points 58 dist to finish 852.6
# step 184 number of isochrone points 60 dist to finish 841.0
# step 185 number of isochrone points 33 dist to finish 826.9
# step 186 number of isochrone points 49 dist to finish 813.6
# step 187 number of isochrone points 50 dist to finish 799.5
# step 188 number of isochrone points 51 dist to finish 786.3
# step 189 number of isochrone points 48 dist to finish 773.2
# step 190 number of isochrone points 47 dist to finish 759.5
# step 191 number of isochrone points 48 dist to finish 744.4
# step 192 number of isochrone points 45 dist to finish 726.9
# step 193 number of isochrone points 48 dist to finish 711.4
# step 194 number of isochrone points 59 dist to finish 695.5
# step 195 number of isochrone points 55 dist to finish 678.6
# step 196 number of isochrone points 56 dist to finish 661.8
# step 197 number of isochrone points 33 dist to finish 645.4
# step 198 number of isochrone points 59 dist to finish 628.5
# step 199 number of isochrone points 30 dist to finish 612.1
# step 200 number of isochrone points 48 dist to finish 595.9
# step 201 number of isochrone points 35 dist to finish 579.3
# step 202 number of isochrone points 49 dist to finish 564.3
# step 203 number of isochrone points 55 dist to finish 548.9
# step 204 number of isochrone points 55 dist to finish 534.1
# step 205 number of isochrone points 53 dist to finish 519.5
# step 206 number of isochrone points 52 dist to finish 504.3
# step 207 number of isochrone points 32 dist to finish 487.4
# step 208 number of isochrone points 39 dist to finish 469.0
# step 209 number of isochrone points 40 dist to finish 450.1
# step 210 number of isochrone points 51 dist to finish 431.4
# step 211 number of isochrone points 42 dist to finish 412.1
# step 212 number of isochrone points 43 dist to finish 391.1
# step 213 number of isochrone points 37 dist to finish 368.4
# step 214 number of isochrone points 13 dist to finish 350.2
# step 215 number of isochrone points 23 dist to finish 337.9
# step 216 number of isochrone points 36 dist to finish 329.4
# step 217 number of isochrone points 40 dist to finish 316.2
# step 218 number of isochrone points 42 dist to finish 295.3
# step 219 number of isochrone points 49 dist to finish 274.0
# step 220 number of isochrone points 58 dist to finish 253.4
# step 221 number of isochrone points 45 dist to finish 232.8
# step 222 number of isochrone points 53 dist to finish 213.6
# step 223 number of isochrone points 57 dist to finish 195.8
# step 224 number of isochrone points 49 dist to finish 178.1
# step 225 number of isochrone points 46 dist to finish 160.2
# step 226 number of isochrone points 59 dist to finish 141.9
# step 227 number of isochrone points 60 dist to finish 123.0
# step 228 number of isochrone points 54 dist to finish 105.0
# step 229 number of isochrone points 45 dist to finish 88.7
# step 230 number of isochrone points 45 dist to finish 77.4
# step 231 number of isochrone points 38 dist to finish 69.2
# step 232 number of isochrone points 35 dist to finish 64.8
# step 233 number of isochrone points 35 dist to finish 60.0
# step 234 number of isochrone points 49 dist to finish 59.6
# step 235 number of isochrone points 51 dist to finish 58.9
# step 236 number of isochrone points 48 dist to finish 58.9
# step 237 number of isochrone points 47 dist to finish 57.9
# step 238 number of isochrone points 44 dist to finish 55.6
# step 239 number of isochrone points 43 dist to finish 54.3
# step 240 number of isochrone points 36 dist to finish 51.1
# step 241 number of isochrone points 39 dist to finish 47.1
# step 242 number of isochrone points 39 dist to finish 45.4
# step 243 number of isochrone points 40 dist to finish 44.2
# step 244 number of isochrone points 45 dist to finish 43.8
# step 245 number of isochrone points 43 dist to finish 42.5
# step 246 number of isochrone points 38 dist to finish 40.5
# step 247 number of isochrone points 32 dist to finish 36.5
# step 248 number of isochrone points 32 dist to finish 31.6
# step 249 number of isochrone points 23 dist to finish 24.3
# step 250 number of isochrone points 30 dist to finish 19.2

# %%
route_df = weatherrouter.get_fastest_route(use_optimized = True)
route_df
# Out:
#            lat        lon                time         twd        tws  \
# 0   -34.000000  18.000000 2025-01-01 12:00:00  232.094025  10.638941
# 1   -33.800724  17.825876 2025-01-01 13:00:00  225.420486  12.146090
# 2   -33.703166  17.563238 2025-01-01 14:00:00  229.544617  13.184561
# 3   -33.556483  17.302768 2025-01-01 15:00:00  221.543182  13.329449
# 4   -33.452931  17.024842 2025-01-01 16:00:00  219.955811  14.590051
# ..         ...        ...                 ...         ...        ...
# 246 -23.321323 -42.604720 2025-01-11 18:00:00  175.966263   9.491061
# 247 -23.430371 -42.694299 2025-01-11 19:00:00  163.784042   7.838160
# 248 -23.344449 -42.778539 2025-01-11 20:00:00  152.387955  10.498222
# 249 -23.249030 -42.911385 2025-01-11 21:00:00  141.190765   9.998202
# 250 -23.167643 -43.009666 2025-01-11 22:00:00  134.219940   9.222569
#
#                                            pos  \
# 0                                (-34.0, 18.0)
# 1    (-33.800723979550014, 17.825876008314737)
# 2       (-33.70316572542025, 17.5632384183725)
# 3     (-33.55648268704515, 17.302767510682006)
# 4    (-33.452930749412054, 17.024842083218115)
# ..                                         ...
# 246   (-23.321322955254978, -42.6047200461372)
# 247  (-23.430370633746602, -42.69429882713071)
# 248   (-23.34444900832425, -42.77853857744019)
# 249   (-23.249029916522396, -42.9113851512398)
# 250   (-23.16764344299585, -43.00966559328329)
#
#                                       next_pos    heading         twa  \
# 0    (-33.800723979550014, 17.825876008314737)  324.00000   91.905975
# 1       (-33.70316572542025, 17.5632384183725)  294.00000   68.579514
# 2     (-33.55648268704515, 17.302767510682006)  304.00000   74.455383
# 3    (-33.452930749412054, 17.024842083218115)  294.00000   72.456818
# 4     (-33.27651265027081, 16.712688522488047)  304.00000   84.044189
# ..                                         ...        ...         ...
# 246  (-23.430370633746602, -42.69429882713071)  217.00000   41.033737
# 247   (-23.34444900832425, -42.77853857744019)  318.00000  154.215958
# 248   (-23.249029916522396, -42.9113851512398)  308.00000  155.612045
# 249   (-23.16764344299585, -43.00966559328329)  312.00000  170.809235
# 250                             (-22.9, -43.2)  326.75989 -167.460051
#
#      base_boat_speed  is_tacking  boat_speed  hours_elapsed  days_elapsed
# 0              14.78       False       14.78              0      0.000000
# 1              14.36       False       14.36              1      0.041667
# 2              15.72       False       15.72              2      0.083333
# 3              15.24       False       15.24              3      0.125000
# 4              18.90       False       18.90              4      0.166667
# ..               ...         ...         ...            ...           ...
# 246             8.20       False        8.20            246     10.250000
# 247             6.94       False        6.94            247     10.291667
# 248             9.30       False        9.30            248     10.333333
# 249             7.30       False        7.30            249     10.375000
# 250             6.88        True        3.44            250     10.416667
#
# [251 rows x 14 columns]

# %%
restricted_isochrones = weatherrouter.get_optimized_isochrones_latlon()

# %%
viz = visualize.visualize(ds.sel(time = slice(route_df.time.values[0], route_df.time.values[-1])), Cape, Rio, route_df, isochrone=restricted_isochrones, filename='route1')
viz.return_plot()
# Out:
# WARNING:param.main: axiswise option not found for image plot with bokeh; similar options include: ['yaxis', 'xaxis']
# WARNING:param.main: axiswise option not found for vectorfield plot with bokeh; similar options include: ['yaxis', 'xaxis']
# BokehModel(combine_events=True, render_bundle={'docs_json': {'0000f403-a85f-468a-80d5-dbd7b766da2a': {'version…
