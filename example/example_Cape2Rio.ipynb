# %%
import intake
import xarray as xr
import zarr
import numpy as np

import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../src/')))
#sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../../weather_routing_old/src/')))

from weather_router import isochronal_weather_router, polar, point_validity, visualize
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='141211d9-17a4-486d-beba-52bfc6c3d6c1'>
#   <div id="d290cd59-cf60-484b-811d-c021e1a1d789" data-root-id="141211d9-17a4-486d-beba-52bfc6c3d6c1" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"fd9ef174-43f7-400d-9990-eb6849429a32":{"version":"3.7.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"141211d9-17a4-486d-beba-52bfc6c3d6c1"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"f31e3b6b-8bce-49b8-b8d4-78730c7b4e12","attributes":{"plot_id":"141211d9-17a4-486d-beba-52bfc6c3d6c1","comm_id":"5120b3458a6d40d88eaf14a769bd6ea2","client_comm_id":"3c52af11a326495a835d23f0f6c216cd"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1" ...
#   var render_items = [{"docid":"fd9ef174-43f7-400d-9990-eb6849429a32","roots":{"141211d9-17a4-486d-beba-52bfc6c3d6c1":"d290cd59-cf60-484b-811d-c021e1a1d789"},"root_ids":["141211d9-17a4-486d-beba-52bfc6c3d6c1"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
#LA = (33.6, -124)
#Honolulu = (21.3, -157.8)

Cape = (-34, 18)
Rio = (-22.9, -43.2)

min_lat = min(Cape[0], Rio[0]) - 5  
max_lat = max(Cape[0], Rio[0]) + 5  

min_lon = min(Cape[1], Rio[1]) - 1  
max_lon = max(Cape[1], Rio[1]) + 1

# %%
if not os.path.exists('cache.zarr/'):
    print('Downloading data...')
    ds = xr.open_zarr(
        'gs://gcp-public-data-arco-era5/ar/full_37-1h-0p25deg-chunk-1.zarr-v3',
        chunks=None,
        storage_options=dict(token='anon'),
    )
    ds = ds.rename({'latitude':'lat', 'longitude':'lon'})
    ds = ds[['10m_u_component_of_wind', '10m_v_component_of_wind']]
    ds.coords['lon'] = ((ds.coords['lon'] + 180) % 360) - 180
    ds = ds.sortby(ds.lon)
    ds = ds.sel(lat=slice(max_lat, min_lat), lon=slice(min_lon, max_lon))
    ds = ds.sel(time = slice('2025-01-01T12:00:00', '2025-01-18T12:00:00'))
    ds = ds.load()
    u10 = ds['10m_u_component_of_wind']
    v10 = ds['10m_v_component_of_wind']
    tws = xr.ufuncs.hypot(v10, u10)
    tws = tws*1.94384 #convert m/s to knots
    twd = (180 + np.rad2deg(np.arctan2(u10, v10))) % 360
    ds = tws.to_dataset(name = 'tws')
    ds['twd'] = twd
    ds.to_zarr('cache.zarr')
else:
    ds = xr.open_zarr('cache.zarr')

# %%
def get_wind(t, lat, lon):
    tws_sel = ds.tws.sel(time = t, method = 'nearest')
    tws_sel = tws_sel.sel(lat = lat, lon = lon, method = 'nearest')
    twd_sel = ds.twd.sel(time = t, method = 'nearest')
    twd_sel = twd_sel.sel(lat = lat, lon = lon, method = 'nearest')
    return (np.float32(twd_sel.values), np.float32(tws_sel.values))

# %%
volvo70_polar = polar.Polar('../test/volvo70.pol')

point_valid = point_validity.land_sea_mask().point_validity_arr

weatherrouter = isochronal_weather_router.weather_router(volvo70_polar, 
                                                         get_wind, 
                                                         time_steps = ds.time.values,
                                                         step = 1,
                                                         start_point = Cape,
                                                         end_point = Rio,
                                                         point_validity = point_valid,
                                                         spread = 140,
                                                         wake_lim = 50,
                                                         rounding = 2,
                                                         n_points=20,
                                                         )

# %%
weatherrouter.route()
# Out:
# 0
# 1
# 8
# 2
# 11
# 3
# 16
# 4
# 16
# 5
# 15
# 6
# 15
# 7
# 16
# 8
# 17
# 9
# 16
# 10
# 15
# 11
# 15
# 12
# 15
# 13
# 15
# 14
# 17
# 15
# 17
# 16
# 16
# 17
# 15
# 18
# 18
# 19
# 19
# 20
# 16
# 21
# 16
# 22
# 18
# 23
# 19
# 24
# 19
# 25
# 17
# 26
# 19
# 27
# 17
# 28
# 19
# 29
# 17
# 30
# 18
# 31
# 12
# 32
# 15
# 33
# 14
# 34
# 14
# 35
# 15
# 36
# 14
# 37
# 15
# 38
# 17
# 39
# 18
# 40
# 15
# 41
# 15
# 42
# 15
# 43
# 18
# 44
# 15
# 45
# 15
# 46
# 17
# 47
# 15
# 48
# 14
# 49
# 16
# 50
# 14
# 51
# 16
# 52
# 16
# 53
# 17
# 54
# 14
# 55
# 14
# 56
# 15
# 57
# 17
# 58
# 18
# 59
# 14
# 60
# 16
# 61
# 15
# 62
# 15
# 63
# 16
# 64
# 18
# 65
# 15
# 66
# 14
# 67
# 14
# 68
# 14
# 69
# 14
# 70
# 16
# 71
# 16
# 72
# 12
# 73
# 15
# 74
# 16
# 75
# 16
# 76
# 16
# 77
# 18
# 78
# 17
# 79
# 16
# 80
# 16
# 81
# 17
# 82
# 15
# 83
# 17
# 84
# 17
# 85
# 15
# 86
# 19
# 87
# 19
# 88
# 18
# 89
# 18
# 90
# 17
# 91
# 15
# 92
# 17
# 93
# 16
# 94
# 19
# 95
# 18
# 96
# 15
# 97
# 18
# 98
# 17
# 99
# 16
# 100
# 17
# 101
# 18
# 102
# 17
# 103
# 19
# 104
# 17
# 105
# 18
# 106
# 20
# 107
# 13
# 108
# 19
# 109
# 15
# 110
# 16
# 111
# 18
# 112
# 14
# 113
# 15
# 114
# 17
# 115
# 17
# 116
# 17
# 117
# 18
# 118
# 17
# 119
# 19
# 120
# 18
# 121
# 17
# 122
# 16
# 123
# 17
# 124
# 13
# 125
# 14
# 126
# 16
# 127
# 9
# 128
# 14
# 129
# 14
# 130
# 14
# 131
# 15
# 132
# 15
# 133
# 18
# 134
# 18
# 135
# 17
# 136
# 17
# 137
# 17
# 138
# 16
# 139
# 17
# 140
# 19
# 141
# 18
# 142
# 18
# 143
# 17
# 144
# 19
# 145
# 14
# 146
# 16
# 147
# 17
# 148
# 15
# 149
# 15
# 150
# 17
# 151
# 15
# 152
# 17
# 153
# 15
# 154
# 15
# 155
# 17
# 156
# 18
# 157
# 16
# 158
# 17
# 159
# 16
# 160
# 16
# 161
# 19
# 162
# 20
# 163
# 17
# 164
# 18
# 165
# 18
# 166
# 19
# 167
# 18
# 168
# 19
# 169
# 18
# 170
# 17
# 171
# 19
# 172
# 15
# 173
# 17
# 174
# 16
# 175
# 17
# 176
# 17
# 177
# 17
# 178
# 17
# 179
# 18
# 180
# 16
# 181
# 19
# 182
# 14
# 183
# 17
# 184
# 15
# 185
# 12
# 186
# 13
# 187
# 13
# 188
# 15
# 189
# 13
# 190
# 16
# 191
# 18
# 192
# 15
# 193
# 16
# 194
# 19
# 195
# 18
# 196
# 18
# 197
# 19
# 198
# 17
# 199
# 19
# 200
# 20
# 201
# 19
# 202
# 17
# 203
# 15
# 204
# 16
# 205
# 14
# 206
# 18
# 207
# 19
# 208
# 15
# 209
# 17
# 210
# 18
# 211
# 19
# 212
# 19
# 213
# 18
# 214
# 18
# 215
# 16
# 216
# 18
# 217
# 13
# 218
# 14
# 219
# 15
# 220
# 18
# 221
# 16
# 222
# 20
# 223
# 17
# 224
# 16
# 225
# 17
# 226
# 15
# 227
# 16
# 228
# 15
# 229
# 15
# 230
# 20
# 231
# 18
# 232
# 15
# 233
# 14
# 234
# 19
# 235
# 19
# 236
# 18
# 237
# 19
# 238
# 18
# 239
# 18
# 240
# 16
# 241
# 16
# 242
# 12
# 243
# 10
# 244
# 10
# 245
# 11
# 246
# 11
# reached dest

# %%
route_df = weatherrouter.get_fastest_route()
route_df
# Out:
#            lat        lon                time         twd        tws  \
# 0   -34.000000  18.000000 2025-01-01 12:00:00  232.094025  10.638941
# 1   -33.835307  17.794896 2025-01-01 13:00:00  225.420486  12.146090
# 2   -33.693109  17.541977 2025-01-01 14:00:00  229.544617  13.184561
# 3   -33.546427  17.281537 2025-01-01 15:00:00  221.543182  13.329449
# 4   -33.394697  17.012621 2025-01-01 16:00:00  219.955811  14.590051
# ..         ...        ...                 ...         ...        ...
# 242 -23.308435 -42.333347 2025-01-11 14:00:00  218.159515   5.847869
# 243 -23.247630 -42.468902 2025-01-11 15:00:00  209.985275   6.507472
# 244 -23.229648 -42.627571 2025-01-11 16:00:00  189.090393   7.897946
# 245 -23.133133 -42.802069 2025-01-11 17:00:00  180.724152   9.306396
# 246 -23.125815 -43.025057 2025-01-11 18:00:00  169.857971  10.715346
#
#                                             pos  \
# 0                                 (-34.0, 18.0)
# 1      (-33.83530685707055, 17.794895521881806)
# 2       (-33.69310947522205, 17.54197715983982)
# 3      (-33.54642654074991, 17.281536568427235)
# 4       (-33.39469681634189, 17.01262078947876)
# ..                                          ...
# 242   (-23.308434768937357, -42.33334738874481)
# 243  (-23.247630100505216, -42.468902014433525)
# 244   (-23.229647736251003, -42.62757087119354)
# 245    (-23.133132834090254, -42.8020690316782)
# 246     (-23.12581488285722, -43.0250570815599)
#
#                                        next_pos     heading         twa  \
# 0      (-33.83530685707055, 17.794895521881806)  314.000000   81.905975
# 1       (-33.69310947522205, 17.54197715983982)  304.000000   78.579514
# 2      (-33.54642654074991, 17.281536568427235)  304.000000   74.455383
# 3       (-33.39469681634189, 17.01262078947876)  304.000000   82.456818
# 4      (-33.218279580868845, 16.70067514572221)  304.000000   84.044189
# ..                                          ...         ...         ...
# 242  (-23.247630100505216, -42.468902014433525)  296.000000   77.840485
# 243   (-23.229647736251003, -42.62757087119354)  277.000000   67.014725
# 244    (-23.133132834090254, -42.8020690316782)  301.000000  111.909607
# 245     (-23.12581488285722, -43.0250570815599)  272.000000   91.275848
# 246                              (-22.9, -43.2)  324.474475  154.616504
#
#      base_boat_speed  is_tacking  boat_speed  hours_elapsed  days_elapsed
# 0              14.22       False       14.22              0      0.000000
# 1              15.24       False       15.24              1      0.041667
# 2              15.72       False       15.72              2      0.083333
# 3              16.26       False       16.26              3      0.125000
# 4              18.90       False       18.90              4      0.166667
# ..               ...         ...         ...            ...           ...
# 242             8.32       False        8.32            242     10.083333
# 243             8.82       False        8.82            243     10.125000
# 244            11.24       False       11.24            244     10.166667
# 245            12.32       False       12.32            245     10.208333
# 246            10.42       False       10.42            246     10.250000
#
# [247 rows x 14 columns]

# %%
initial_route = weatherrouter.get_fastest_route(stats=False)
initial_isochrones = weatherrouter.get_isochrones()

optimized_route = weatherrouter.optimize(initial_route, initial_isochrones)
# Out:
# Starting optimization pass...
# constraint overriden
# Optimize step 0
# Optimize step 1
# Optimize isochrone points: 8, dist_wp_min: 3240.8694949076935
# Optimize step 2
# Optimize isochrone points: 16, dist_wp_min: 3228.829613075504
# Optimize step 3
# Optimize isochrone points: 31, dist_wp_min: 3216.154573560798
# Optimize step 4
# Optimize isochrone points: 23, dist_wp_min: 3203.472043082612
# Optimize step 5
# Optimize isochrone points: 24, dist_wp_min: 3188.0917680532125
# Optimize step 6
# Optimize isochrone points: 26, dist_wp_min: 3172.175882764353
# Optimize step 7
# Optimize isochrone points: 26, dist_wp_min: 3155.4485818442163
# Optimize step 8
# Optimize isochrone points: 25, dist_wp_min: 3138.2207194449775
# Optimize step 9
# Optimize isochrone points: 26, dist_wp_min: 3120.297248599958
# Optimize step 10
# Optimize isochrone points: 28, dist_wp_min: 3103.6138894538676
# Optimize step 11
# Optimize isochrone points: 27, dist_wp_min: 3087.881150875804
# Optimize step 12
# Optimize isochrone points: 24, dist_wp_min: 3071.9251931528133
# Optimize step 13
# Optimize isochrone points: 26, dist_wp_min: 3052.3326344280304
# Optimize step 14
# Optimize isochrone points: 23, dist_wp_min: 3031.332811254541
# Optimize step 15
# Optimize isochrone points: 31, dist_wp_min: 3013.293407670116
# Optimize step 16
# Optimize isochrone points: 26, dist_wp_min: 2994.7906963737446
# Optimize step 17
# Optimize isochrone points: 26, dist_wp_min: 2977.0549704513064
# Optimize step 18
# Optimize isochrone points: 24, dist_wp_min: 2960.622555161989
# Optimize step 19
# Optimize isochrone points: 31, dist_wp_min: 2945.8101633962365
# Optimize step 20
# Optimize isochrone points: 28, dist_wp_min: 2932.574080675641
# Optimize step 21
# Optimize isochrone points: 30, dist_wp_min: 2919.8383630677076
# Optimize step 22
# Optimize isochrone points: 29, dist_wp_min: 2905.950937862562
# Optimize step 23
# Optimize isochrone points: 32, dist_wp_min: 2893.3326504820398
# Optimize step 24
# Optimize isochrone points: 31, dist_wp_min: 2882.8797816413316
# Optimize step 25
# Optimize isochrone points: 33, dist_wp_min: 2873.019819616805
# Optimize step 26
# Optimize isochrone points: 33, dist_wp_min: 2864.563693288661
# Optimize step 27
# Optimize isochrone points: 33, dist_wp_min: 2854.9712779532747
# Optimize step 28
# Optimize isochrone points: 27, dist_wp_min: 2845.348812583095
# Optimize step 29
# Optimize isochrone points: 29, dist_wp_min: 2834.363355202881
# Optimize step 30
# Optimize isochrone points: 27, dist_wp_min: 2823.3750746744768
# Optimize step 31
# Optimize isochrone points: 26, dist_wp_min: 2812.2064112474386
# Optimize step 32
# Optimize isochrone points: 25, dist_wp_min: 2802.227210680776
# Optimize step 33
# Optimize isochrone points: 29, dist_wp_min: 2791.511993172202
# Optimize step 34
# Optimize isochrone points: 29, dist_wp_min: 2781.710308825493
# Optimize step 35
# Optimize isochrone points: 30, dist_wp_min: 2773.5425170230988
# Optimize step 36
# Optimize isochrone points: 27, dist_wp_min: 2766.914811831306
# Optimize step 37
# Optimize isochrone points: 28, dist_wp_min: 2760.611457563078
# Optimize step 38
# Optimize isochrone points: 32, dist_wp_min: 2755.098907113883
# Optimize step 39
# Optimize isochrone points: 32, dist_wp_min: 2751.1013366979237
# Optimize step 40
# Optimize isochrone points: 37, dist_wp_min: 2748.8059161004244
# Optimize step 41
# Optimize isochrone points: 38, dist_wp_min: 2747.488078992139
# Optimize step 42
# Optimize isochrone points: 30, dist_wp_min: 2742.107593745724
# Optimize step 43
# Optimize isochrone points: 30, dist_wp_min: 2736.187707162733
# Optimize step 44
# Optimize isochrone points: 34, dist_wp_min: 2727.6314519709013
# Optimize step 45
# Optimize isochrone points: 32, dist_wp_min: 2717.938023298175
# Optimize step 46
# Optimize isochrone points: 28, dist_wp_min: 2706.0014585943495
# Optimize step 47
# Optimize isochrone points: 27, dist_wp_min: 2691.485978376923
# Optimize step 48
# Optimize isochrone points: 29, dist_wp_min: 2678.3922814346242
# Optimize step 49
# Optimize isochrone points: 24, dist_wp_min: 2665.601065282547
# Optimize step 50
# Optimize isochrone points: 27, dist_wp_min: 2651.811489618184
# Optimize step 51
# Optimize isochrone points: 25, dist_wp_min: 2637.5957646938414
# Optimize step 52
# Optimize isochrone points: 24, dist_wp_min: 2625.2573814765146
# Optimize step 53
# Optimize isochrone points: 27, dist_wp_min: 2613.2672738761976
# Optimize step 54
# Optimize isochrone points: 24, dist_wp_min: 2601.675519510948
# Optimize step 55
# Optimize isochrone points: 25, dist_wp_min: 2590.373622462819
# Optimize step 56
# Optimize isochrone points: 28, dist_wp_min: 2577.801963114131
# Optimize step 57
# Optimize isochrone points: 24, dist_wp_min: 2567.3373707678393
# Optimize step 58
# Optimize isochrone points: 31, dist_wp_min: 2559.675430558459
# Optimize step 59
# Optimize isochrone points: 29, dist_wp_min: 2542.4095787434458
# Optimize step 60
# Optimize isochrone points: 27, dist_wp_min: 2525.1351724016918
# Optimize step 61
# Optimize isochrone points: 26, dist_wp_min: 2508.3427996176633
# Optimize step 62
# Optimize isochrone points: 39, dist_wp_min: 2492.618333515121
# Optimize step 63
# Optimize isochrone points: 25, dist_wp_min: 2476.3020178382253
# Optimize step 64
# Optimize isochrone points: 25, dist_wp_min: 2459.978750593753
# Optimize step 65
# Optimize isochrone points: 23, dist_wp_min: 2444.5773834895167
# Optimize step 66
# Optimize isochrone points: 22, dist_wp_min: 2428.3333683918695
# Optimize step 67
# Optimize isochrone points: 25, dist_wp_min: 2412.083181959415
# Optimize step 68
# Optimize isochrone points: 24, dist_wp_min: 2396.372440290934
# Optimize step 69
# Optimize isochrone points: 27, dist_wp_min: 2380.6562534323566
# Optimize step 70
# Optimize isochrone points: 24, dist_wp_min: 2364.520711279541
# Optimize step 71
# Optimize isochrone points: 27, dist_wp_min: 2348.480609230714
# Optimize step 72
# Optimize isochrone points: 24, dist_wp_min: 2333.4397240431263
# Optimize step 73
# Optimize isochrone points: 28, dist_wp_min: 2318.059686588619
# Optimize step 74
# Optimize isochrone points: 27, dist_wp_min: 2304.0262075313485
# Optimize step 75
# Optimize isochrone points: 24, dist_wp_min: 2288.955905980218
# Optimize step 76
# Optimize isochrone points: 29, dist_wp_min: 2273.55424828713
# Optimize step 77
# Optimize isochrone points: 27, dist_wp_min: 2257.7923915557008
# Optimize step 78
# Optimize isochrone points: 25, dist_wp_min: 2240.9092445513324
# Optimize step 79
# Optimize isochrone points: 23, dist_wp_min: 2223.7444760447233
# Optimize step 80
# Optimize isochrone points: 29, dist_wp_min: 2205.351735333737
# Optimize step 81
# Optimize isochrone points: 28, dist_wp_min: 2186.341111713571
# Optimize step 82
# Optimize isochrone points: 27, dist_wp_min: 2167.529106147084
# Optimize step 83
# Optimize isochrone points: 28, dist_wp_min: 2149.569251390794
# Optimize step 84
# Optimize isochrone points: 27, dist_wp_min: 2131.3697354566443
# Optimize step 85
# Optimize isochrone points: 25, dist_wp_min: 2113.8005145787542
# Optimize step 86
# Optimize isochrone points: 26, dist_wp_min: 2096.225718841959
# Optimize step 87
# Optimize isochrone points: 24, dist_wp_min: 2078.6328007409793
# Optimize step 88
# Optimize isochrone points: 24, dist_wp_min: 2061.445063173062
# Optimize step 89
# Optimize isochrone points: 24, dist_wp_min: 2044.3015549118659
# Optimize step 90
# Optimize isochrone points: 29, dist_wp_min: 2028.5475361115173
# Optimize step 91
# Optimize isochrone points: 27, dist_wp_min: 2010.8071279745975
# Optimize step 92
# Optimize isochrone points: 27, dist_wp_min: 1993.0821571735803
# Optimize step 93
# Optimize isochrone points: 27, dist_wp_min: 1976.9363370004698
# Optimize step 94
# Optimize isochrone points: 28, dist_wp_min: 1960.9432483096425
# Optimize step 95
# Optimize isochrone points: 28, dist_wp_min: 1944.3026512007486
# Optimize step 96
# Optimize isochrone points: 28, dist_wp_min: 1929.161183133855
# Optimize step 97
# Optimize isochrone points: 30, dist_wp_min: 1914.356054139368
# Optimize step 98
# Optimize isochrone points: 32, dist_wp_min: 1901.2788359023862
# Optimize step 99
# Optimize isochrone points: 32, dist_wp_min: 1889.584996902306
# Optimize step 100
# Optimize isochrone points: 31, dist_wp_min: 1879.5022818981042
# Optimize step 101
# Optimize isochrone points: 27, dist_wp_min: 1869.645686663902
# Optimize step 102
# Optimize isochrone points: 33, dist_wp_min: 1861.1696983927802
# Optimize step 103
# Optimize isochrone points: 33, dist_wp_min: 1853.4386241498291
# Optimize step 104
# Optimize isochrone points: 30, dist_wp_min: 1845.8584089493716
# Optimize step 105
# Optimize isochrone points: 29, dist_wp_min: 1840.466765800386
# Optimize step 106
# Optimize isochrone points: 31, dist_wp_min: 1834.3714661083739
# Optimize step 107
# Optimize isochrone points: 28, dist_wp_min: 1824.2064107412243
# Optimize step 108
# Optimize isochrone points: 35, dist_wp_min: 1814.8461625035304
# Optimize step 109
# Optimize isochrone points: 32, dist_wp_min: 1806.448043341586
# Optimize step 110
# Optimize isochrone points: 28, dist_wp_min: 1800.5020029066138
# Optimize step 111
# Optimize isochrone points: 31, dist_wp_min: 1792.7266378325817
# Optimize step 112
# Optimize isochrone points: 24, dist_wp_min: 1784.329166949235
# Optimize step 113
# Optimize isochrone points: 24, dist_wp_min: 1777.097897001321
# Optimize step 114
# Optimize isochrone points: 31, dist_wp_min: 1769.4767027678272
# Optimize step 115
# Optimize isochrone points: 31, dist_wp_min: 1759.8459349331804
# Optimize step 116
# Optimize isochrone points: 28, dist_wp_min: 1748.932517371983
# Optimize step 117
# Optimize isochrone points: 30, dist_wp_min: 1737.6934191128594
# Optimize step 118
# Optimize isochrone points: 35, dist_wp_min: 1727.71450760693
# Optimize step 119
# Optimize isochrone points: 30, dist_wp_min: 1718.1950855811863
# Optimize step 120
# Optimize isochrone points: 30, dist_wp_min: 1706.0672658052229
# Optimize step 121
# Optimize isochrone points: 31, dist_wp_min: 1693.6379420344797
# Optimize step 122
# Optimize isochrone points: 34, dist_wp_min: 1681.0179681607083
# Optimize step 123
# Optimize isochrone points: 35, dist_wp_min: 1669.6980727902687
# Optimize step 124
# Optimize isochrone points: 32, dist_wp_min: 1659.6982738073461
# Optimize step 125
# Optimize isochrone points: 33, dist_wp_min: 1650.1688029164004
# Optimize step 126
# Optimize isochrone points: 32, dist_wp_min: 1640.4806285352954
# Optimize step 127
# Optimize isochrone points: 30, dist_wp_min: 1631.154319357963
# Optimize step 128
# Optimize isochrone points: 35, dist_wp_min: 1621.8097660796213
# Optimize step 129
# Optimize isochrone points: 34, dist_wp_min: 1612.4485238202647
# Optimize step 130
# Optimize isochrone points: 32, dist_wp_min: 1603.1987910232062
# Optimize step 131
# Optimize isochrone points: 29, dist_wp_min: 1595.4018279826516
# Optimize step 132
# Optimize isochrone points: 28, dist_wp_min: 1583.8709602644833
# Optimize step 133
# Optimize isochrone points: 31, dist_wp_min: 1571.4058133136339
# Optimize step 134
# Optimize isochrone points: 31, dist_wp_min: 1558.4277024014286
# Optimize step 135
# Optimize isochrone points: 28, dist_wp_min: 1545.9319390653343
# Optimize step 136
# Optimize isochrone points: 34, dist_wp_min: 1533.8921905707534
# Optimize step 137
# Optimize isochrone points: 33, dist_wp_min: 1522.524554199918
# Optimize step 138
# Optimize isochrone points: 34, dist_wp_min: 1509.319447389753
# Optimize step 139
# Optimize isochrone points: 29, dist_wp_min: 1496.2133376232505
# Optimize step 140
# Optimize isochrone points: 29, dist_wp_min: 1481.8415029452967
# Optimize step 141
# Optimize isochrone points: 28, dist_wp_min: 1468.1257381840899
# Optimize step 142
# Optimize isochrone points: 29, dist_wp_min: 1453.7363098518388
# Optimize step 143
# Optimize isochrone points: 25, dist_wp_min: 1440.369747330853
# Optimize step 144
# Optimize isochrone points: 29, dist_wp_min: 1426.2578848798914
# Optimize step 145
# Optimize isochrone points: 25, dist_wp_min: 1413.1693741949812
# Optimize step 146
# Optimize isochrone points: 27, dist_wp_min: 1402.2280492620996
# Optimize step 147
# Optimize isochrone points: 30, dist_wp_min: 1387.8128402305977
# Optimize step 148
# Optimize isochrone points: 26, dist_wp_min: 1373.459528790083
# Optimize step 149
# Optimize isochrone points: 31, dist_wp_min: 1360.5441630775244
# Optimize step 150
# Optimize isochrone points: 30, dist_wp_min: 1348.3910085274183
# Optimize step 151
# Optimize isochrone points: 33, dist_wp_min: 1335.1740334107355
# Optimize step 152
# Optimize isochrone points: 30, dist_wp_min: 1321.0157125364437
# Optimize step 153
# Optimize isochrone points: 28, dist_wp_min: 1306.6844232951078
# Optimize step 154
# Optimize isochrone points: 27, dist_wp_min: 1292.5001095566793
# Optimize step 155
# Optimize isochrone points: 27, dist_wp_min: 1277.8847872330332
# Optimize step 156
# Optimize isochrone points: 19, dist_wp_min: 1263.5070755116515
# Optimize step 157
# Optimize isochrone points: 25, dist_wp_min: 1249.4006691852808
# Optimize step 158
# Optimize isochrone points: 28, dist_wp_min: 1236.5014701921784
# Optimize step 159
# Optimize isochrone points: 27, dist_wp_min: 1221.862154536356
# Optimize step 160
# Optimize isochrone points: 30, dist_wp_min: 1207.5003510954614
# Optimize step 161
# Optimize isochrone points: 28, dist_wp_min: 1193.1462757520928
# Optimize step 162
# Optimize isochrone points: 29, dist_wp_min: 1181.304271344703
# Optimize step 163
# Optimize isochrone points: 27, dist_wp_min: 1172.0787069155049
# Optimize step 164
# Optimize isochrone points: 26, dist_wp_min: 1164.0093502150085
# Optimize step 165
# Optimize isochrone points: 28, dist_wp_min: 1149.9361141137051
# Optimize step 166
# Optimize isochrone points: 31, dist_wp_min: 1130.8529176377588
# Optimize step 167
# Optimize isochrone points: 32, dist_wp_min: 1113.928634922767
# Optimize step 168
# Optimize isochrone points: 33, dist_wp_min: 1102.1854770868583
# Optimize step 169
# Optimize isochrone points: 29, dist_wp_min: 1086.1218211432856
# Optimize step 170
# Optimize isochrone points: 31, dist_wp_min: 1069.8669927212934
# Optimize step 171
# Optimize isochrone points: 29, dist_wp_min: 1055.7516375452444
# Optimize step 172
# Optimize isochrone points: 27, dist_wp_min: 1042.2368004636662
# Optimize step 173
# Optimize isochrone points: 28, dist_wp_min: 1028.5147112935451
# Optimize step 174
# Optimize isochrone points: 31, dist_wp_min: 1015.1223215754816
# Optimize step 175
# Optimize isochrone points: 30, dist_wp_min: 1001.793295816946
# Optimize step 176
# Optimize isochrone points: 29, dist_wp_min: 990.4591550826078
# Optimize step 177
# Optimize isochrone points: 28, dist_wp_min: 978.3625475809255
# Optimize step 178
# Optimize isochrone points: 31, dist_wp_min: 966.3775076386239
# Optimize step 179
# Optimize isochrone points: 33, dist_wp_min: 953.2538183159945
# Optimize step 180
# Optimize isochrone points: 23, dist_wp_min: 940.5318389599746
# Optimize step 181
# Optimize isochrone points: 23, dist_wp_min: 926.8253630295418
# Optimize step 182
# Optimize isochrone points: 24, dist_wp_min: 911.8847470018262
# Optimize step 183
# Optimize isochrone points: 25, dist_wp_min: 897.1939400995884
# Optimize step 184
# Optimize isochrone points: 27, dist_wp_min: 882.8722649519971
# Optimize step 185
# Optimize isochrone points: 23, dist_wp_min: 865.7934224745247
# Optimize step 186
# Optimize isochrone points: 18, dist_wp_min: 850.5281287004786
# Optimize step 187
# Optimize isochrone points: 20, dist_wp_min: 836.5790082008278
# Optimize step 188
# Optimize isochrone points: 22, dist_wp_min: 823.3996106781389
# Optimize step 189
# Optimize isochrone points: 18, dist_wp_min: 808.8537083010282
# Optimize step 190
# Optimize isochrone points: 23, dist_wp_min: 796.0058267701958
# Optimize step 191
# Optimize isochrone points: 23, dist_wp_min: 783.0054519892057
# Optimize step 192
# Optimize isochrone points: 22, dist_wp_min: 770.0029726744419
# Optimize step 193
# Optimize isochrone points: 23, dist_wp_min: 756.387461674766
# Optimize step 194
# Optimize isochrone points: 32, dist_wp_min: 742.2842811297915
# Optimize step 195
# Optimize isochrone points: 28, dist_wp_min: 728.660906754384
# Optimize step 196
# Optimize isochrone points: 29, dist_wp_min: 714.1357338062178
# Optimize step 197
# Optimize isochrone points: 30, dist_wp_min: 698.9058182859437
# Optimize step 198
# Optimize isochrone points: 34, dist_wp_min: 684.1860529394243
# Optimize step 199
# Optimize isochrone points: 33, dist_wp_min: 668.6494831825987
# Optimize step 200
# Optimize isochrone points: 35, dist_wp_min: 652.9863020468882
# Optimize step 201
# Optimize isochrone points: 32, dist_wp_min: 638.6257581739608
# Optimize step 202
# Optimize isochrone points: 35, dist_wp_min: 621.488421851526
# Optimize step 203
# Optimize isochrone points: 32, dist_wp_min: 603.844658951476
# Optimize step 204
# Optimize isochrone points: 31, dist_wp_min: 586.1995351968396
# Optimize step 205
# Optimize isochrone points: 31, dist_wp_min: 568.6488898456918
# Optimize step 206
# Optimize isochrone points: 27, dist_wp_min: 550.9874014906184
# Optimize step 207
# Optimize isochrone points: 27, dist_wp_min: 531.7450641499235
# Optimize step 208
# Optimize isochrone points: 29, dist_wp_min: 514.085230567204
# Optimize step 209
# Optimize isochrone points: 30, dist_wp_min: 495.42754092256064
# Optimize step 210
# Optimize isochrone points: 29, dist_wp_min: 475.96043578807775
# Optimize step 211
# Optimize isochrone points: 28, dist_wp_min: 454.79879212425516
# Optimize step 212
# Optimize isochrone points: 23, dist_wp_min: 431.6458681934392
# Optimize step 213
# Optimize isochrone points: 29, dist_wp_min: 407.47533139364276
# Optimize step 214
# Optimize isochrone points: 29, dist_wp_min: 384.02432274547147
# Optimize step 215
# Optimize isochrone points: 32, dist_wp_min: 360.9233618076452
# Optimize step 216
# Optimize isochrone points: 33, dist_wp_min: 340.70853997650136
# Optimize step 217
# Optimize isochrone points: 26, dist_wp_min: 328.57305782730754
# Optimize step 218
# Optimize isochrone points: 31, dist_wp_min: 320.6005686969896
# Optimize step 219
# Optimize isochrone points: 34, dist_wp_min: 300.0578770978366
# Optimize step 220
# Optimize isochrone points: 32, dist_wp_min: 279.42657587537855
# Optimize step 221
# Optimize isochrone points: 26, dist_wp_min: 258.58150289862226
# Optimize step 222
# Optimize isochrone points: 34, dist_wp_min: 238.26377911447693
# Optimize step 223
# Optimize isochrone points: 35, dist_wp_min: 217.84255639818272
# Optimize step 224
# Optimize isochrone points: 34, dist_wp_min: 198.24424644323415
# Optimize step 225
# Optimize isochrone points: 36, dist_wp_min: 178.6470690459074
# Optimize step 226
# Optimize isochrone points: 39, dist_wp_min: 157.64715935229322
# Optimize step 227
# Optimize isochrone points: 38, dist_wp_min: 136.74753465692552
# Optimize step 228
# Optimize isochrone points: 37, dist_wp_min: 117.60875253163698
# Optimize step 229
# Optimize isochrone points: 34, dist_wp_min: 101.0443801087174
# Optimize step 230
# Optimize isochrone points: 32, dist_wp_min: 88.72279355064998
# Optimize step 231
# Optimize isochrone points: 31, dist_wp_min: 79.85107717311375
# Optimize step 232
# Optimize isochrone points: 30, dist_wp_min: 71.50714682833521
# Optimize step 233
# Optimize isochrone points: 24, dist_wp_min: 62.181231307130986
# Optimize step 234
# Optimize isochrone points: 32, dist_wp_min: 53.362673854278746
# Optimize step 235
# Optimize isochrone points: 27, dist_wp_min: 45.65639142659231
# Optimize step 236
# Optimize isochrone points: 23, dist_wp_min: 40.04190847963313
# Optimize step 237
# Optimize isochrone points: 15, dist_wp_min: 33.47927699396906
# Optimize step 238
# Optimize isochrone points: 8, dist_wp_min: 28.037514071355055
# Optimize step 239
# Optimize isochrone points: 6, dist_wp_min: 23.94078052302288
# Optimize step 240
# Optimize isochrone points: 10, dist_wp_min: 20.705520073796883
# Optimize step 241
# Optimize isochrone points: 15, dist_wp_min: 18.490587955111007
# optimization reached dest
# Optimization pass complete

# %%
route_df = weatherrouter.get_fastest_route()
route_df
# Out:
#            lat        lon                time         twd        tws  \
# 0   -34.000000  18.000000 2025-01-01 12:00:00  232.094025  10.638941
# 1   -33.835307  17.794896 2025-01-01 13:00:00  225.420486  12.146090
# 2   -33.693109  17.541977 2025-01-01 14:00:00  229.544617  13.184561
# 3   -33.546427  17.281537 2025-01-01 15:00:00  221.543182  13.329449
# 4   -33.394697  17.012621 2025-01-01 16:00:00  219.955811  14.590051
# ..         ...        ...                 ...         ...        ...
# 237 -23.277431 -42.681106 2025-01-11 09:00:00  260.664612   6.398579
# 238 -23.189528 -42.767188 2025-01-11 10:00:00  237.338730   4.357839
# 239 -23.154030 -42.849931 2025-01-11 11:00:00  235.891174   4.296618
# 240 -23.132191 -42.922966 2025-01-11 12:00:00  233.223206   3.782576
# 241 -23.130414 -42.977991 2025-01-11 13:00:00  233.345886   4.226319
#
#                                             pos  \
# 0                                 (-34.0, 18.0)
# 1      (-33.83530685707055, 17.794895521881806)
# 2       (-33.69310947522205, 17.54197715983982)
# 3      (-33.54642654074991, 17.281536568427235)
# 4       (-33.39469681634189, 17.01262078947876)
# ..                                          ...
# 237  (-23.277430679641643, -42.681106248339084)
# 238   (-23.18952779334511, -42.767187984567656)
# 239   (-23.15403020925716, -42.849931314948776)
# 240  (-23.132190927294733, -42.922965836365265)
# 241   (-23.130414334780408, -42.97799072828037)
#
#                                        next_pos     heading        twa  \
# 0      (-33.83530685707055, 17.794895521881806)  314.000000  81.905975
# 1       (-33.69310947522205, 17.54197715983982)  304.000000  78.579514
# 2      (-33.54642654074991, 17.281536568427235)  304.000000  74.455383
# 3       (-33.39469681634189, 17.01262078947876)  304.000000  82.456818
# 4      (-33.218279580868845, 16.70067514572221)  304.000000  84.044189
# ..                                          ...         ...        ...
# 237   (-23.18952779334511, -42.767187984567656)  318.000000  57.335388
# 238   (-23.15403020925716, -42.849931314948776)  295.000000  57.661270
# 239  (-23.132190927294733, -42.922965836365265)  288.000000  52.108826
# 240   (-23.130414334780408, -42.97799072828037)  272.000000  38.776794
# 241                              (-22.9, -43.2)  318.389077  85.043191
#
#      base_boat_speed  is_tacking  boat_speed  hours_elapsed  days_elapsed
# 0              14.22       False       14.22              0      0.000000
# 1              15.24       False       15.24              1      0.041667
# 2              15.72       False       15.72              2      0.083333
# 3              16.26       False       16.26              3      0.125000
# 4              18.90       False       18.90              4      0.166667
# ..               ...         ...         ...            ...           ...
# 237             7.10       False        7.10            237      9.875000
# 238             5.04       False        5.04            238      9.916667
# 239             4.24       False        4.24            239      9.958333
# 240             3.04       False        3.04            240     10.000000
# 241             5.76       False        5.76            241     10.041667
#
# [242 rows x 14 columns]

# %%
route_df.columns
# Out:
# Index(['lat', 'lon', 'time', 'twd', 'tws', 'pos', 'next_pos', 'heading', 'twa',
#        'base_boat_speed', 'is_tacking', 'boat_speed', 'hours_elapsed',
#        'days_elapsed'],
#       dtype='object')

# %%
import holoviews as hv
hv.extension('bokeh')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='ae7336b0-7a0e-4b27-beeb-af0bf43b1b02'>
#   <div id="b1b5ab95-e8f1-4352-b8a3-75a62e5df0f7" data-root-id="ae7336b0-7a0e-4b27-beeb-af0bf43b1b02" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"c06165f4-8882-4f7f-a7ff-9c1867309804":{"version":"3.7.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"ae7336b0-7a0e-4b27-beeb-af0bf43b1b02"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"a454ccbc-fbfe-4dcf-9703-fb2780b8b24f","attributes":{"plot_id":"ae7336b0-7a0e-4b27-beeb-af0bf43b1b02","comm_id":"ad2d500d53e6460092e0bfe8f3baeb62","client_comm_id":"9d85b9bf75e74722869c5b24fee6771a"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1" ...
#   var render_items = [{"docid":"c06165f4-8882-4f7f-a7ff-9c1867309804","roots":{"ae7336b0-7a0e-4b27-beeb-af0bf43b1b02":"b1b5ab95-e8f1-4352-b8a3-75a62e5df0f7"},"root_ids":["ae7336b0-7a0e-4b27-beeb-af0bf43b1b02"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
viz = visualize.visualize(ds, Cape, Rio, route_df, filename='route1')
viz.return_plot()
# Out:
# BokehModel(combine_events=True, render_bundle={'docs_json': {'fec3ae53-db87-4e4c-a88e-afecf229d095': {'version…
